# %%
# Install required packages
# !pip install -q transformers
# !pip install -q peft==0.5.0
# !pip install -q accelerate
# !pip install -q bitsandbytes
# !pip install -q sentencepiece
# !pip install -q torch
# !pip install -q pandas
# !pip install -q numpy
# !pip install -q scikit-learn
# !pip install -q matplotlib
# !pip install -q yfinance
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 9.0 MB/s eta 0:00:00

# %%
import os
import torch
import pandas as pd
import yfinance as yf
from datetime import datetime, timedelta
from tqdm import tqdm
import warnings
from google.colab import auth
from oauth2client.client import GoogleCredentials
from pydrive2.auth import GoogleAuth
from pydrive2.drive import GoogleDrive
warnings.filterwarnings('ignore')


class StockDataManager:
    def __init__(self):
        self.dirs = ['data', 'models', 'results']
        self.setup_directories()

    def setup_directories(self):
        for dir_name in self.dirs:
            os.makedirs(dir_name, exist_ok=True)
            print(f"Created/verified directory: {dir_name}/")

    # Download StockEmo data
    def download_stockemo_data(self):
        # Authenticate
        auth.authenticate_user()
        gauth = GoogleAuth()
        gauth.credentials = GoogleCredentials.get_application_default()
        drive = GoogleDrive(gauth)

        file_ids = {
            "train_stockemo.csv": "14kpQhdpjt57ySe9omZSofbmFF4iYUIDc",
            "val_stockemo.csv": "1-8FC0f1RDCNSkRt8doTDMAPrmdmazQ5u",
            "test_stockemo.csv": "1-A1n7mRMbje-me1rQpce_QsfFnlH0av7",
            "processed_stockemo.csv": "1-7QLxjVIezZLJ_Og5m3DmmW32BabnH2i"
        }

        for filename, file_id in file_ids.items():
            output_path = f"data/{filename}"
            if not os.path.exists(output_path):
                print(f"Downloading {filename}...")
                downloaded = drive.CreateFile({"id": file_id})
                downloaded.GetContentFile(output_path)
                print(f"Saved to {output_path}")
            else:
                print(f"{filename} already exists")

    def get_unique_tickers_from_stockemo(self):
        """Get list of unique tickers from processed_stockemo.csv"""
        try:
            processed_df = pd.read_csv("data/processed_stockemo.csv")
            unique_tickers = processed_df['ticker'].unique().tolist()
            print(f"Found {len(unique_tickers)} unique tickers in StockEmo data")
            return unique_tickers
        except Exception as e:
            print(f"Error reading StockEmo data: {str(e)}")
            return []

    def download_stock_data(self, start_date=None, end_date=None, period=None):
        """
        Download stock data for all StockEmo tickers
        """
        # Get symbols from StockEmo
        symbols = self.get_unique_tickers_from_stockemo()

        if not symbols:
            raise ValueError("No tickers found in StockEmo data")

        # Handle dates
        if period and not (start_date or end_date):
            valid_periods = ['1d','5d','1mo','3mo','6mo','1y','2y','5y','10y','ytd','max']
            if period not in valid_periods:
                raise ValueError(f"Invalid period. Must be one of {valid_periods}")
        else:
            if not start_date:
                start_date = (datetime.now() - timedelta(days=365)).strftime('%Y-%m-%d')
            if not end_date:
                end_date = datetime.now().strftime('%Y-%m-%d')

        stock_data = {}
        print("\nDownloading stock data...")
        for symbol in tqdm(symbols, desc="Downloading stock data"):
            try:
                # Create Ticker object
                ticker = yf.Ticker(symbol)

                # Get historical data
                if period:
                    hist = ticker.history(period=period)
                else:
                    hist = ticker.history(start=start_date, end=end_date)

                if not hist.empty:
                    # Convert to DataFrame and reset index
                    df = hist.reset_index()

                    # Add ticker column
                    df.insert(0, 'Ticker', symbol)

                    # Save to CSV
                    output_path = f"data/{symbol}_prices.csv"
                    df.to_csv(output_path, index=False)

                    stock_data[symbol] = df
                else:
                    print(f"\nNo data received for {symbol}")

            except Exception as e:
                print(f"\nError downloading {symbol}: {str(e)}")
                continue

        print(f"\nSuccessfully downloaded data for {len(stock_data)} tickers")
        return stock_data

def initialize_workspace(start_date=None, end_date=None, period=None):
    """Initialize workspace and download stock data"""
    print("Setting up workspace...")
    manager = StockDataManager()

    manager.download_stockemo_data()

    stock_data = manager.download_stock_data(
        start_date=start_date,
        end_date=end_date,
        period=period
    )

    # Print summary of downloaded data
    print("\nDownloaded Data Summary:")
    for symbol, df in stock_data.items():
        print(f"\n{symbol}:")
        print(f"Date Range: {df['Date'].min()} to {df['Date'].max()}")
        print(f"Number of records: {len(df)}")

    return manager, stock_data

if __name__ == "__main__":
    # Download data for all StockEmo tickers
    manager, data = initialize_workspace(
    start_date='2020-01-01',
    end_date='2020-12-31'
)

    # Print total number of tickers downloaded
    print(f"\nTotal number of tickers downloaded: {len(data)}")
# Out:
# Setting up workspace...
# Created/verified directory: data/
# Created/verified directory: models/
# Created/verified directory: results/
# Downloading train_stockemo.csv...
# Saved to data/train_stockemo.csv
# Downloading val_stockemo.csv...
# Saved to data/val_stockemo.csv
# Downloading test_stockemo.csv...
# Saved to data/test_stockemo.csv
# Downloading processed_stockemo.csv...
# Saved to data/processed_stockemo.csv
# Found 39 unique tickers in StockEmo data
#
# Downloading stock data...
# Downloading stock data:  15%|█▌        | 6/39 [00:00<00:04,  6.70it/s]ERROR:yfinance:$FB: possibly delisted; no timezone found
# Downloading stock data:  23%|██▎       | 9/39 [00:01<00:05,  5.04it/s]
# No data received for FB
# Downloading stock data:  85%|████████▍ | 33/39 [00:05<00:00,  6.63it/s]ERROR:yfinance:$BRK.A: possibly delisted; no timezone found
# Downloading stock data:  87%|████████▋ | 34/39 [00:06<00:01,  3.62it/s]
# No data received for BRK.A
# ERROR:yfinance:$BRK.B: possibly delisted; no timezone found
# Downloading stock data:  92%|█████████▏| 36/39 [00:06<00:00,  3.46it/s]
# No data received for BRK.B
# Downloading stock data: 100%|██████████| 39/39 [00:07<00:00,  5.28it/s]
# Successfully downloaded data for 36 tickers
#
# Downloaded Data Summary:
#
# AAPL:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# AMT:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# AMZN:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# BA:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# BKNG:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# DIS:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# MA:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# GOOGL:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# MCD:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# GOOG:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# NFLX:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# HD:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# NKE:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# JNJ:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# PFE:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# JPM:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# SBUX:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# MSFT:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# TM:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# NVDA:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# TSM:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# PG:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# UPS:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# PYPL:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# ABNB:
# Date Range: 2020-12-10 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 14
#
# TSLA:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# UNH:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# V:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# BABA:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# WMT:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# XOM:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# BAC:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# CCL:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# CVX:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# KO:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# LOW:
# Date Range: 2020-01-02 00:00:00-05:00 to 2020-12-30 00:00:00-05:00
# Number of records: 252
#
# Total number of tickers downloaded: 36

# %%
import torch
import torch.nn as nn
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from typing import Dict, List, Tuple
import gc

class SentimentDataset(Dataset):
    def __init__(self, processed_df, price_df, sequence_length, sentiment_model):
        processed_df['date'] = pd.to_datetime(processed_df['date'])
        price_df['Date'] = pd.to_datetime(price_df['Date'])

        self.processed_df = processed_df.sort_values('date')
        self.price_df = price_df.sort_values('Date')
        self.sequence_length = sequence_length
        self.sentiment_model = sentiment_model

        self.scaler = MinMaxScaler()
        self.prices_scaled = self.scaler.fit_transform(self.price_df['Close'].values.reshape(-1, 1)).flatten()

    def __len__(self):
        return len(self.processed_df) - self.sequence_length

    def __getitem__(self, idx):
        text = self.processed_df.iloc[idx]['processed']
        sentiment_score = self.sentiment_model.get_sentiment(text)
        features = torch.tensor([sentiment_score], dtype=torch.float32)

        price_seq = torch.tensor(self.prices_scaled[idx:idx+self.sequence_length], dtype=torch.float32)
        target = torch.tensor(self.prices_scaled[idx+self.sequence_length], dtype=torch.float32)

        return features, price_seq, target

class SentimentModel:
    def __init__(self, device="cuda" if torch.cuda.is_available() else "cpu"):
        self.device = device
        print(f"Initializing FinBERT model on {device}")

        self.tokenizer = AutoTokenizer.from_pretrained('ProsusAI/finbert')
        self.model = AutoModelForSequenceClassification.from_pretrained(
            'ProsusAI/finbert'
        ).to(device)
        self.model.eval()
        print("Model loaded successfully!")

    def get_sentiment(self, text):
        try:
            inputs = self.tokenizer(
                text,
                return_tensors="pt",
                truncation=True,
                max_length=512
            ).to(self.device)

            with torch.no_grad():
                outputs = self.model(**inputs)
                probs = torch.softmax(outputs.logits, dim=1)
                score = probs[0][2].item() - probs[0][0].item()
            return score
        except Exception as e:
            print(f"Error in sentiment analysis: {str(e)}")
            return 0.0

def analyze_sentiments_by_ticker(processed_df, sentiment_model, batch_size=32):
    results = []
    processed_df['date'] = pd.to_datetime(processed_df['date'])
    grouped = processed_df.groupby('ticker')

    print("\nAnalyzing sentiments for each ticker...")
    for ticker, group in tqdm(grouped, desc="Processing tickers"):
        ticker_results = []

        for i in range(0, len(group), batch_size):
            batch = group.iloc[i:i + batch_size]

            for _, row in batch.iterrows():
                text = row['processed']
                sentiment_score = sentiment_model.get_sentiment(text)

                ticker_results.append({
                    'date': row['date'],
                    'ticker': ticker,
                    'text': text,
                    'sentiment': sentiment_score,
                    'original_sentiment': row['senti_label'],
                    'industry': row['industry']
                })

        ticker_df = pd.DataFrame(ticker_results)
        ticker_df.to_csv(f"data/{ticker}_sentiment_analysis.csv", index=False)
        results.extend(ticker_results)

    return pd.DataFrame(results)

def main():
    print("Initializing stock data download...")
    manager = StockDataManager()
    stock_data = manager.download_stock_data(start_date='2020-01-01',end_date='2020-12-31')
    print("\nLoading StockEmo data...")
    processed_df = pd.read_csv("data/processed_stockemo.csv")

    sentiment_model = SentimentModel()
    results_df = analyze_sentiments_by_ticker(processed_df, sentiment_model)
    results_df.to_csv("data/all_tickers_sentiment_analysis.csv", index=False)
    print("\nSaved sentiment analysis results to data/all_tickers_sentiment_analysis.csv")

    return sentiment_model, results_df, stock_data

if __name__ == "__main__":
    sentiment_model, sentiment_results, stock_data = main()

    print("\nAnalysis Summary:")
    print(f"Number of tickers analyzed: {len(sentiment_results['ticker'].unique())}")
    print("\nSentiment distribution:")
    print(sentiment_results['sentiment'].describe())
# Out:
# Initializing stock data download...
# Created/verified directory: data/
# Created/verified directory: models/
# Created/verified directory: results/
# Found 39 unique tickers in StockEmo data
#
# Downloading stock data...
# Downloading stock data:  15%|█▌        | 6/39 [00:00<00:04,  7.80it/s]ERROR:yfinance:$FB: possibly delisted; no timezone found
# Downloading stock data:  18%|█▊        | 7/39 [00:01<00:09,  3.54it/s]
# No data received for FB
# Downloading stock data:  82%|████████▏ | 32/39 [00:02<00:00, 24.42it/s]ERROR:yfinance:$BRK.A: possibly delisted; no timezone found
# ERROR:yfinance:$BRK.B: possibly delisted; no timezone found
# Downloading stock data: 100%|██████████| 39/39 [00:02<00:00, 13.34it/s]
# No data received for BRK.A
#
# No data received for BRK.B
#
# Successfully downloaded data for 36 tickers
#
# Loading StockEmo data...
# Initializing FinBERT model on cuda
# tokenizer_config.json:   0%|          | 0.00/252 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/758 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Model loaded successfully!
#
# Analyzing sentiments for each ticker...
# Processing tickers:   0%|          | 0/39 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Processing tickers: 100%|██████████| 39/39 [07:46<00:00, 11.96s/it]
# Saved sentiment analysis results to data/all_tickers_sentiment_analysis.csv
#
# Analysis Summary:
# Number of tickers analyzed: 39
#
# Sentiment distribution:
# count    50281.000000
# mean         0.662058
# std          0.334808
# min         -0.941154
# 25%          0.627737
# 50%          0.791516
# 75%          0.857522
# max          0.933513
# Name: sentiment, dtype: float64

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from typing import Dict, List, Tuple
import os

class SentimentLSTM(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, dropout=0.2):
        super().__init__()

        self.hidden_dim = hidden_dim
        self.num_layers = num_layers

        self.lstm = nn.LSTM(
            input_dim,
            hidden_dim,
            num_layers,
            batch_first=True,
            dropout=dropout if num_layers > 1 else 0
        )

        self.fc = nn.Linear(hidden_dim, 1)

    def forward(self, x_sentiment, x_price):
        batch_size = x_price.size(0)
        seq_length = x_price.size(1)

        x_sentiment = x_sentiment.unsqueeze(1).repeat(1, seq_length, 1)
        x_combined = torch.cat((x_sentiment, x_price.unsqueeze(-1)), dim=2)

        h0 = torch.zeros(self.num_layers, batch_size, self.hidden_dim).to(x_combined.device)
        c0 = torch.zeros(self.num_layers, batch_size, self.hidden_dim).to(x_combined.device)

        out, _ = self.lstm(x_combined, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out.squeeze()

class BaselineLSTM(nn.Module):
    def __init__(self, hidden_dim, num_layers, dropout=0.2):
        super().__init__()

        self.hidden_dim = hidden_dim
        self.num_layers = num_layers

        self.lstm = nn.LSTM(
            1,  # Only price input
            hidden_dim,
            num_layers,
            batch_first=True,
            dropout=dropout if num_layers > 1 else 0
        )

        self.fc = nn.Linear(hidden_dim, 1)

    def forward(self, x_price):
        batch_size = x_price.size(0)

        h0 = torch.zeros(self.num_layers, batch_size, self.hidden_dim).to(x_price.device)
        c0 = torch.zeros(self.num_layers, batch_size, self.hidden_dim).to(x_price.device)

        out, _ = self.lstm(x_price.unsqueeze(-1), (h0, c0))
        out = self.fc(out[:, -1, :])
        return out.squeeze()

class TickerDataset(Dataset):
    def __init__(self, price_df, sentiment_df, sequence_length):
        price_df = price_df.copy()
        sentiment_df = sentiment_df.copy()

        # Convert price dates to YYYY-MM-DD
        price_df['Date'] = price_df['Date'].astype(str).str[:10]

        # # Debug print
        # print("\nPrice dates sample:", price_df['Date'].head().tolist())
        # print("Sentiment dates sample:", sentiment_df['date'].head().tolist())
        # print("\nTotal unique price dates:", len(price_df['Date'].unique()))
        # print("Total unique sentiment dates:", len(sentiment_df['date'].unique()))
        # print("\nSample overlap:", len(set(price_df['Date']) & set(sentiment_df['date'])))

        self.price_df = price_df[price_df['Date'].isin(sentiment_df['date'])]
        self.sentiment_df = sentiment_df

        print(f"Matched data points: {len(self.price_df)}")

        if len(self.price_df) < sequence_length + 1:
            raise ValueError(f"Insufficient data points. Need at least {sequence_length + 1} points, got {len(self.price_df)}")

        self.scaler = MinMaxScaler()
        self.prices_scaled = self.scaler.fit_transform(self.price_df['Close'].values.reshape(-1, 1)).flatten()

        self.sequence_length = sequence_length
        self.sentiments = self.sentiment_df['sentiment'].values

    def __len__(self):
        return len(self.prices_scaled) - self.sequence_length - 1

    def __getitem__(self, idx):
        sentiment = torch.tensor([self.sentiments[idx]], dtype=torch.float32)
        price_seq = torch.tensor(self.prices_scaled[idx:idx+self.sequence_length], dtype=torch.float32)
        target = torch.tensor(self.prices_scaled[idx+self.sequence_length], dtype=torch.float32)
        return sentiment, price_seq, target

    def inverse_transform(self, scaled_values):
        return self.scaler.inverse_transform(scaled_values.reshape(-1, 1)).flatten()

class BaselineDataset(Dataset):
    def __init__(self, price_df, sequence_length):
        self.price_df = price_df.copy()
        self.sequence_length = sequence_length

        self.scaler = MinMaxScaler()
        self.prices_scaled = self.scaler.fit_transform(self.price_df['Close'].values.reshape(-1, 1)).flatten()

    def __len__(self):
        return len(self.prices_scaled) - self.sequence_length - 1

    def __getitem__(self, idx):
        price_seq = torch.tensor(self.prices_scaled[idx:idx+self.sequence_length], dtype=torch.float32)
        target = torch.tensor(self.prices_scaled[idx+self.sequence_length], dtype=torch.float32)
        return price_seq, target

    def inverse_transform(self, scaled_values):
        return self.scaler.inverse_transform(scaled_values.reshape(-1, 1)).flatten()


def validate_data_files(tickers: List[str]) -> List[str]:
    valid_tickers = []
    for ticker in tickers:
        sentiment_path = f"data/{ticker}_sentiment_analysis.csv"
        price_path = f"data/{ticker}_prices.csv"

        if os.path.exists(sentiment_path) and os.path.exists(price_path):
            try:
                sentiment_df = pd.read_csv(sentiment_path)
                price_df = pd.read_csv(price_path)
                if len(sentiment_df) > 0 and len(price_df) > 0:
                    valid_tickers.append(ticker)
                else:
                    print(f"Warning: Empty data files for {ticker}")
            except Exception as e:
                print(f"Error reading data for {ticker}: {str(e)}")
        else:
            print(f"Warning: Missing data files for {ticker}")

    print(f"Found {len(valid_tickers)} valid tickers out of {len(tickers)} total")
    return valid_tickers

def train_and_evaluate_ticker(ticker: str, model_params: Dict, train_params: Dict) -> Tuple[List[float], List[float]]:
    price_df = pd.read_csv(f"data/{ticker}_prices.csv")
    sentiment_df = pd.read_csv(f"data/{ticker}_sentiment_analysis.csv")

    dataset = TickerDataset(price_df, sentiment_df, model_params['sequence_length'])

    train_size = int(0.8 * len(dataset))
    val_size = len(dataset) - train_size
    train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

    train_loader = DataLoader(train_dataset, batch_size=train_params['batch_size'], shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=train_params['batch_size'])

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = SentimentLSTM(
        model_params['input_dim'],
        model_params['hidden_dim'],
        model_params['num_layers']
    ).to(device)

    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=train_params['learning_rate'])

    for epoch in range(train_params['epochs']):
        model.train()
        train_loss = 0
        for sentiment, price_seq, target in train_loader:
            sentiment, price_seq, target = sentiment.to(device), price_seq.to(device), target.to(device)

            optimizer.zero_grad()
            output = model(sentiment, price_seq)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        if epoch % 10 == 0:
            print(f'{ticker} - Epoch {epoch}: Loss = {train_loss/len(train_loader):.4f}')

    model.eval()
    predictions = []
    actuals = []

    with torch.no_grad():
        for sentiment, price_seq, target in val_loader:
            sentiment, price_seq = sentiment.to(device), price_seq.to(device)
            output = model(sentiment, price_seq)
            predictions.extend(output.cpu().numpy())
            actuals.extend(target.numpy())

    predictions = dataset.inverse_transform(np.array(predictions))
    actuals = dataset.inverse_transform(np.array(actuals))

    return predictions, actuals

def train_and_evaluate_baseline(ticker: str, model_params: Dict, train_params: Dict) -> Tuple[List[float], List[float]]:
    price_df = pd.read_csv(f"data/{ticker}_prices.csv")
    price_df['Date'] = price_df['Date'].astype(str).str[:10]

    dataset = BaselineDataset(price_df, model_params['sequence_length'])

    train_size = int(0.8 * len(dataset))
    val_size = len(dataset) - train_size
    train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

    train_loader = DataLoader(train_dataset, batch_size=train_params['batch_size'], shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=train_params['batch_size'])

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = BaselineLSTM(
        model_params['hidden_dim'],
        model_params['num_layers']
    ).to(device)

    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=train_params['learning_rate'])

    for epoch in range(train_params['epochs']):
        model.train()
        train_loss = 0
        for price_seq, target in train_loader:
            price_seq, target = price_seq.to(device), target.to(device)

            optimizer.zero_grad()
            output = model(price_seq)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        if epoch % 10 == 0:
            print(f'{ticker} Baseline - Epoch {epoch}: Loss = {train_loss/len(train_loader):.4f}')

    model.eval()
    predictions = []
    actuals = []

    with torch.no_grad():
        for price_seq, target in val_loader:
            price_seq = price_seq.to(device)
            output = model(price_seq)
            predictions.extend(output.cpu().numpy())
            actuals.extend(target.numpy())

    predictions = dataset.inverse_transform(np.array(predictions))
    actuals = dataset.inverse_transform(np.array(actuals))

    return predictions, actuals

def plot_comparison(ticker: str, sentiment_pred: List[float], baseline_pred: List[float], actuals: List[float]):
    plt.figure(figsize=(15, 10))

    # Price Comparison Plot
    plt.plot(actuals, label='Actual', color='blue', linewidth=2)
    plt.plot(sentiment_pred, label='LSTM with Sentiment', color='red', linestyle='--', linewidth=2)
    plt.plot(baseline_pred, label='Baseline LSTM', color='green', linestyle='--', linewidth=2)

    plt.title(f'Price Predictions Comparison for {ticker}')
    plt.xlabel('Time Steps')
    plt.ylabel('Price')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.savefig(f'results/{ticker}_comparison.png')
    plt.close()


def plot_results(ticker: str, predictions: List[float], actuals: List[float]):
    plt.figure(figsize=(15, 10))

    # Create subplots
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 12))

    # Price Comparison Plot
    ax1.plot(actuals, label='Actual', color='blue', linewidth=2)
    ax1.plot(predictions, label='Predicted', color='red', linestyle='--', linewidth=2)
    ax1.set_title(f'Price Predictions vs Actual for {ticker}')
    ax1.set_xlabel('Time Steps')
    ax1.set_ylabel('Price')
    ax1.legend()
    ax1.grid(True)

    # Error Analysis Plot
    errors = np.array(predictions) - np.array(actuals)
    ax2.plot(errors, color='green', label='Prediction Error')
    ax2.axhline(y=0, color='r', linestyle='-', alpha=0.3)
    ax2.set_title('Prediction Error Over Time')
    ax2.set_xlabel('Time Steps')
    ax2.set_ylabel('Error (Predicted - Actual)')
    ax2.legend()
    ax2.grid(True)

    plt.tight_layout()
    plt.savefig(f'results/{ticker}_analysis.png')
    plt.close()

def plot_mse_comparison(results_df):
    # Filter successful predictions only
    df = results_df[results_df['status'] == 'success']

    plt.figure(figsize=(15, 8))

    # Create grouped bars for MSE comparison
    tickers = df.index
    x = np.arange(len(tickers))
    width = 0.35

    plt.bar(x - width/2, df['sentiment_mse'], width, label='LSTM with Sentiment', color='blue', alpha=0.7)
    plt.bar(x + width/2, df['baseline_mse'], width, label='Baseline LSTM', color='red', alpha=0.7)

    plt.xlabel('Tickers')
    plt.ylabel('Mean Squared Error (MSE)')
    plt.title('MSE Comparison: Sentiment LSTM vs Baseline LSTM')
    plt.xticks(x, tickers, rotation=45)
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    plt.savefig('results/mse_comparison.png')
    plt.close()

    # Calculate and print average improvement
    avg_improvement = df['improvement'].mean()
    print(f"\nAverage MSE Improvement: {avg_improvement:.2f}%")

    # Print individual MSE comparisons
    print("\nMSE Comparison by Ticker:")
    for ticker in df.index:
        print(f"{ticker}:")
        print(f"  Sentiment LSTM MSE: {df.loc[ticker, 'sentiment_mse']:.6f}")
        print(f"  Baseline LSTM MSE: {df.loc[ticker, 'baseline_mse']:.6f}")
        print(f"  Improvement: {df.loc[ticker, 'improvement']:.2f}%")


def main():
    model_params = {
        'input_dim': 2, #2 for sentiment, 1 for baseline
        'hidden_dim': 25,  # Best performing hidden size
        'num_layers': 2,
        'sequence_length': 5  # Best performing window size
    }

    train_params = {
        'batch_size': 32,
        'epochs': 250,  # Best performing epoch count
        'learning_rate': 0.001,
        'train_split': 0.67  # 67% train, 33% test
    }

    all_tickers = [f.split('_')[0] for f in os.listdir('data') if f.endswith('_sentiment_analysis.csv')]
    valid_tickers = validate_data_files(all_tickers)

    os.makedirs('results', exist_ok=True)

    results = {}
    for ticker in valid_tickers:
        print(f"\nProcessing {ticker}")
        try:
            sentiment_pred, sentiment_actuals = train_and_evaluate_ticker(ticker, model_params, train_params)
            baseline_pred, baseline_actuals = train_and_evaluate_baseline(ticker, model_params, train_params)

            sentiment_mse = np.mean((sentiment_pred - sentiment_actuals) ** 2)
            sentiment_mae = np.mean(np.abs(sentiment_pred - sentiment_actuals))
            baseline_mse = np.mean((baseline_pred - baseline_actuals) ** 2)
            baseline_mae = np.mean(np.abs(baseline_pred - baseline_actuals))

            results[ticker] = {
                'sentiment_mse': sentiment_mse,
                'sentiment_mae': sentiment_mae,
                'baseline_mse': baseline_mse,
                'baseline_mae': baseline_mae,
                'improvement': ((baseline_mse - sentiment_mse) / baseline_mse) * 100,
                'status': 'success'
            }

            plot_results(ticker, sentiment_pred, sentiment_actuals)
            plot_comparison(ticker, sentiment_pred, baseline_pred, sentiment_actuals)

        except Exception as e:
            print(f"Error processing {ticker}: {str(e)}")
            results[ticker] = {
                'sentiment_mse': None,
                'sentiment_mae': None,
                'baseline_mse': None,
                'baseline_mae': None,
                'improvement': None,
                'status': f'failed: {str(e)}'
            }

    results_df = pd.DataFrame.from_dict(results, orient='index')
    results_df.to_csv('results/model_comparison_metrics.csv')
    plot_mse_comparison(results_df)


    success_count = sum(1 for v in results.values() if v['status'] == 'success')
    print(f"\nProcessing complete:")
    print(f"Successfully processed: {success_count}/{len(valid_tickers)} tickers")
    print(f"Results saved to: results/model_comparison_metrics.csv")

if __name__ == '__main__':
    main()
# Out:
# Warning: Missing data files for BRK.B
# Warning: Missing data files for BRK.A
# Warning: Missing data files for FB
# Warning: Missing data files for all
# Found 36 valid tickers out of 40 total
#
# Processing BA
# Matched data points: 218
# BA - Epoch 0: Loss = 0.2290
# BA - Epoch 10: Loss = 0.0330
# BA - Epoch 20: Loss = 0.0069
# BA - Epoch 30: Loss = 0.0063
# BA - Epoch 40: Loss = 0.0056
# BA - Epoch 50: Loss = 0.0081
# BA - Epoch 60: Loss = 0.0056
# BA - Epoch 70: Loss = 0.0051
# BA - Epoch 80: Loss = 0.0050
# BA - Epoch 90: Loss = 0.0058
# BA - Epoch 100: Loss = 0.0050
# BA - Epoch 110: Loss = 0.0055
# BA - Epoch 120: Loss = 0.0049
# BA - Epoch 130: Loss = 0.0048
# BA - Epoch 140: Loss = 0.0049
# BA - Epoch 150: Loss = 0.0049
# BA - Epoch 160: Loss = 0.0045
# BA - Epoch 170: Loss = 0.0043
# BA - Epoch 180: Loss = 0.0043
# BA - Epoch 190: Loss = 0.0039
# BA - Epoch 200: Loss = 0.0043
# BA - Epoch 210: Loss = 0.0037
# BA - Epoch 220: Loss = 0.0027
# BA - Epoch 230: Loss = 0.0035
# BA - Epoch 240: Loss = 0.0031
# BA Baseline - Epoch 0: Loss = 0.2495
# BA Baseline - Epoch 10: Loss = 0.0491
# BA Baseline - Epoch 20: Loss = 0.0075
# BA Baseline - Epoch 30: Loss = 0.0054
# BA Baseline - Epoch 40: Loss = 0.0054
# BA Baseline - Epoch 50: Loss = 0.0048
# BA Baseline - Epoch 60: Loss = 0.0061
# BA Baseline - Epoch 70: Loss = 0.0045
# BA Baseline - Epoch 80: Loss = 0.0043
# BA Baseline - Epoch 90: Loss = 0.0044
# BA Baseline - Epoch 100: Loss = 0.0039
# BA Baseline - Epoch 110: Loss = 0.0049
# BA Baseline - Epoch 120: Loss = 0.0048
# BA Baseline - Epoch 130: Loss = 0.0053
# BA Baseline - Epoch 140: Loss = 0.0045
# BA Baseline - Epoch 150: Loss = 0.0041
# BA Baseline - Epoch 160: Loss = 0.0039
# BA Baseline - Epoch 170: Loss = 0.0040
# BA Baseline - Epoch 180: Loss = 0.0044
# BA Baseline - Epoch 190: Loss = 0.0039
# BA Baseline - Epoch 200: Loss = 0.0037
# BA Baseline - Epoch 210: Loss = 0.0037
# BA Baseline - Epoch 220: Loss = 0.0031
# BA Baseline - Epoch 230: Loss = 0.0038
# BA Baseline - Epoch 240: Loss = 0.0033
#
# Processing CCL
# Matched data points: 147
# CCL - Epoch 0: Loss = 0.0827
# CCL - Epoch 10: Loss = 0.0121
# CCL - Epoch 20: Loss = 0.0106
# CCL - Epoch 30: Loss = 0.0053
# CCL - Epoch 40: Loss = 0.0044
# CCL - Epoch 50: Loss = 0.0041
# CCL - Epoch 60: Loss = 0.0040
# CCL - Epoch 70: Loss = 0.0042
# CCL - Epoch 80: Loss = 0.0042
# CCL - Epoch 90: Loss = 0.0035
# CCL - Epoch 100: Loss = 0.0039
# CCL - Epoch 110: Loss = 0.0036
# CCL - Epoch 120: Loss = 0.0037
# CCL - Epoch 130: Loss = 0.0033
# CCL - Epoch 140: Loss = 0.0035
# CCL - Epoch 150: Loss = 0.0031
# CCL - Epoch 160: Loss = 0.0030
# CCL - Epoch 170: Loss = 0.0028
# CCL - Epoch 180: Loss = 0.0027
# CCL - Epoch 190: Loss = 0.0028
# CCL - Epoch 200: Loss = 0.0024
# CCL - Epoch 210: Loss = 0.0022
# CCL - Epoch 220: Loss = 0.0021
# CCL - Epoch 230: Loss = 0.0023
# CCL - Epoch 240: Loss = 0.0022
# CCL Baseline - Epoch 0: Loss = 0.1125
# CCL Baseline - Epoch 10: Loss = 0.0226
# CCL Baseline - Epoch 20: Loss = 0.0037
# CCL Baseline - Epoch 30: Loss = 0.0025
# CCL Baseline - Epoch 40: Loss = 0.0024
# CCL Baseline - Epoch 50: Loss = 0.0035
# CCL Baseline - Epoch 60: Loss = 0.0026
# CCL Baseline - Epoch 70: Loss = 0.0027
# CCL Baseline - Epoch 80: Loss = 0.0026
# CCL Baseline - Epoch 90: Loss = 0.0030
# CCL Baseline - Epoch 100: Loss = 0.0024
# CCL Baseline - Epoch 110: Loss = 0.0025
# CCL Baseline - Epoch 120: Loss = 0.0027
# CCL Baseline - Epoch 130: Loss = 0.0029
# CCL Baseline - Epoch 140: Loss = 0.0024
# CCL Baseline - Epoch 150: Loss = 0.0027
# CCL Baseline - Epoch 160: Loss = 0.0026
# CCL Baseline - Epoch 170: Loss = 0.0024
# CCL Baseline - Epoch 180: Loss = 0.0024
# CCL Baseline - Epoch 190: Loss = 0.0021
# CCL Baseline - Epoch 200: Loss = 0.0022
# CCL Baseline - Epoch 210: Loss = 0.0025
# CCL Baseline - Epoch 220: Loss = 0.0020
# CCL Baseline - Epoch 230: Loss = 0.0021
# CCL Baseline - Epoch 240: Loss = 0.0021
#
# Processing PG
# Matched data points: 13
# PG - Epoch 0: Loss = 0.2391
# PG - Epoch 10: Loss = 0.1649
# PG - Epoch 20: Loss = 0.1052
# PG - Epoch 30: Loss = 0.0647
# PG - Epoch 40: Loss = 0.0645
# PG - Epoch 50: Loss = 0.0613
# PG - Epoch 60: Loss = 0.0636
# PG - Epoch 70: Loss = 0.0607
# PG - Epoch 80: Loss = 0.0613
# PG - Epoch 90: Loss = 0.0639
# PG - Epoch 100: Loss = 0.0590
# PG - Epoch 110: Loss = 0.0604
# PG - Epoch 120: Loss = 0.0584
# PG - Epoch 130: Loss = 0.0563
# PG - Epoch 140: Loss = 0.0604
# PG - Epoch 150: Loss = 0.0537
# PG - Epoch 160: Loss = 0.0567
# PG - Epoch 170: Loss = 0.0577
# PG - Epoch 180: Loss = 0.0609
# PG - Epoch 190: Loss = 0.0518
# PG - Epoch 200: Loss = 0.0503
# PG - Epoch 210: Loss = 0.0497
# PG - Epoch 220: Loss = 0.0380
# PG - Epoch 230: Loss = 0.0411
# PG - Epoch 240: Loss = 0.0199
# PG Baseline - Epoch 0: Loss = 0.3409
# PG Baseline - Epoch 10: Loss = 0.0372
# PG Baseline - Epoch 20: Loss = 0.0098
# PG Baseline - Epoch 30: Loss = 0.0048
# PG Baseline - Epoch 40: Loss = 0.0042
# PG Baseline - Epoch 50: Loss = 0.0041
# PG Baseline - Epoch 60: Loss = 0.0042
# PG Baseline - Epoch 70: Loss = 0.0036
# PG Baseline - Epoch 80: Loss = 0.0037
# PG Baseline - Epoch 90: Loss = 0.0036
# PG Baseline - Epoch 100: Loss = 0.0038
# PG Baseline - Epoch 110: Loss = 0.0037
# PG Baseline - Epoch 120: Loss = 0.0032
# PG Baseline - Epoch 130: Loss = 0.0034
# PG Baseline - Epoch 140: Loss = 0.0044
# PG Baseline - Epoch 150: Loss = 0.0032
# PG Baseline - Epoch 160: Loss = 0.0034
# PG Baseline - Epoch 170: Loss = 0.0045
# PG Baseline - Epoch 180: Loss = 0.0031
# PG Baseline - Epoch 190: Loss = 0.0031
# PG Baseline - Epoch 200: Loss = 0.0029
# PG Baseline - Epoch 210: Loss = 0.0028
# PG Baseline - Epoch 220: Loss = 0.0027
# PG Baseline - Epoch 230: Loss = 0.0034
# PG Baseline - Epoch 240: Loss = 0.0031
#
# Processing TSM
# Matched data points: 29
# TSM - Epoch 0: Loss = 0.2283
# TSM - Epoch 10: Loss = 0.1375
# TSM - Epoch 20: Loss = 0.0658
# TSM - Epoch 30: Loss = 0.0485
# TSM - Epoch 40: Loss = 0.0456
# TSM - Epoch 50: Loss = 0.0416
# TSM - Epoch 60: Loss = 0.0391
# TSM - Epoch 70: Loss = 0.0362
# TSM - Epoch 80: Loss = 0.0338
# TSM - Epoch 90: Loss = 0.0291
# TSM - Epoch 100: Loss = 0.0223
# TSM - Epoch 110: Loss = 0.0178
# TSM - Epoch 120: Loss = 0.0143
# TSM - Epoch 130: Loss = 0.0141
# TSM - Epoch 140: Loss = 0.0139
# TSM - Epoch 150: Loss = 0.0128
# TSM - Epoch 160: Loss = 0.0161
# TSM - Epoch 170: Loss = 0.0117
# TSM - Epoch 180: Loss = 0.0138
# TSM - Epoch 190: Loss = 0.0138
# TSM - Epoch 200: Loss = 0.0143
# TSM - Epoch 210: Loss = 0.0133
# TSM - Epoch 220: Loss = 0.0139
# TSM - Epoch 230: Loss = 0.0119
# TSM - Epoch 240: Loss = 0.0124
# TSM Baseline - Epoch 0: Loss = 0.2166
# TSM Baseline - Epoch 10: Loss = 0.0545
# TSM Baseline - Epoch 20: Loss = 0.0034
# TSM Baseline - Epoch 30: Loss = 0.0029
# TSM Baseline - Epoch 40: Loss = 0.0025
# TSM Baseline - Epoch 50: Loss = 0.0037
# TSM Baseline - Epoch 60: Loss = 0.0020
# TSM Baseline - Epoch 70: Loss = 0.0025
# TSM Baseline - Epoch 80: Loss = 0.0020
# TSM Baseline - Epoch 90: Loss = 0.0023
# TSM Baseline - Epoch 100: Loss = 0.0023
# TSM Baseline - Epoch 110: Loss = 0.0019
# TSM Baseline - Epoch 120: Loss = 0.0021
# TSM Baseline - Epoch 130: Loss = 0.0016
# TSM Baseline - Epoch 140: Loss = 0.0018
# TSM Baseline - Epoch 150: Loss = 0.0020
# TSM Baseline - Epoch 160: Loss = 0.0015
# TSM Baseline - Epoch 170: Loss = 0.0014
# TSM Baseline - Epoch 180: Loss = 0.0014
# TSM Baseline - Epoch 190: Loss = 0.0016
# TSM Baseline - Epoch 200: Loss = 0.0019
# TSM Baseline - Epoch 210: Loss = 0.0014
# TSM Baseline - Epoch 220: Loss = 0.0018
# TSM Baseline - Epoch 230: Loss = 0.0013
# TSM Baseline - Epoch 240: Loss = 0.0012
#
# Processing HD
# Matched data points: 71
# HD - Epoch 0: Loss = 0.9700
# HD - Epoch 10: Loss = 0.5555
# HD - Epoch 20: Loss = 0.0623
# HD - Epoch 30: Loss = 0.0484
# HD - Epoch 40: Loss = 0.0394
# HD - Epoch 50: Loss = 0.0374
# HD - Epoch 60: Loss = 0.0350
# HD - Epoch 70: Loss = 0.0238
# HD - Epoch 80: Loss = 0.0217
# HD - Epoch 90: Loss = 0.0220
# HD - Epoch 100: Loss = 0.0189
# HD - Epoch 110: Loss = 0.0186
# HD - Epoch 120: Loss = 0.0196
# HD - Epoch 130: Loss = 0.0190
# HD - Epoch 140: Loss = 0.0166
# HD - Epoch 150: Loss = 0.0161
# HD - Epoch 160: Loss = 0.0171
# HD - Epoch 170: Loss = 0.0194
# HD - Epoch 180: Loss = 0.0151
# HD - Epoch 190: Loss = 0.0172
# HD - Epoch 200: Loss = 0.0173
# HD - Epoch 210: Loss = 0.0160
# HD - Epoch 220: Loss = 0.0163
# HD - Epoch 230: Loss = 0.0168
# HD - Epoch 240: Loss = 0.0181
# HD Baseline - Epoch 0: Loss = 0.4216
# HD Baseline - Epoch 10: Loss = 0.0317
# HD Baseline - Epoch 20: Loss = 0.0103
# HD Baseline - Epoch 30: Loss = 0.0059
# HD Baseline - Epoch 40: Loss = 0.0055
# HD Baseline - Epoch 50: Loss = 0.0067
# HD Baseline - Epoch 60: Loss = 0.0072
# HD Baseline - Epoch 70: Loss = 0.0046
# HD Baseline - Epoch 80: Loss = 0.0048
# HD Baseline - Epoch 90: Loss = 0.0043
# HD Baseline - Epoch 100: Loss = 0.0042
# HD Baseline - Epoch 110: Loss = 0.0042
# HD Baseline - Epoch 120: Loss = 0.0034
# HD Baseline - Epoch 130: Loss = 0.0037
# HD Baseline - Epoch 140: Loss = 0.0045
# HD Baseline - Epoch 150: Loss = 0.0041
# HD Baseline - Epoch 160: Loss = 0.0048
# HD Baseline - Epoch 170: Loss = 0.0040
# HD Baseline - Epoch 180: Loss = 0.0037
# HD Baseline - Epoch 190: Loss = 0.0035
# HD Baseline - Epoch 200: Loss = 0.0073
# HD Baseline - Epoch 210: Loss = 0.0035
# HD Baseline - Epoch 220: Loss = 0.0029
# HD Baseline - Epoch 230: Loss = 0.0031
# HD Baseline - Epoch 240: Loss = 0.0030
#
# Processing PYPL
# Matched data points: 87
# PYPL - Epoch 0: Loss = 0.3746
# PYPL - Epoch 10: Loss = 0.1279
# PYPL - Epoch 20: Loss = 0.0536
# PYPL - Epoch 30: Loss = 0.0443
# PYPL - Epoch 40: Loss = 0.0380
# PYPL - Epoch 50: Loss = 0.0321
# PYPL - Epoch 60: Loss = 0.0239
# PYPL - Epoch 70: Loss = 0.0126
# PYPL - Epoch 80: Loss = 0.0077
# PYPL - Epoch 90: Loss = 0.0073
# PYPL - Epoch 100: Loss = 0.0075
# PYPL - Epoch 110: Loss = 0.0069
# PYPL - Epoch 120: Loss = 0.0060
# PYPL - Epoch 130: Loss = 0.0053
# PYPL - Epoch 140: Loss = 0.0061
# PYPL - Epoch 150: Loss = 0.0060
# PYPL - Epoch 160: Loss = 0.0054
# PYPL - Epoch 170: Loss = 0.0052
# PYPL - Epoch 180: Loss = 0.0062
# PYPL - Epoch 190: Loss = 0.0057
# PYPL - Epoch 200: Loss = 0.0056
# PYPL - Epoch 210: Loss = 0.0056
# PYPL - Epoch 220: Loss = 0.0055
# PYPL - Epoch 230: Loss = 0.0048
# PYPL - Epoch 240: Loss = 0.0053
# PYPL Baseline - Epoch 0: Loss = 0.4416
# PYPL Baseline - Epoch 10: Loss = 0.0442
# PYPL Baseline - Epoch 20: Loss = 0.0040
# PYPL Baseline - Epoch 30: Loss = 0.0047
# PYPL Baseline - Epoch 40: Loss = 0.0038
# PYPL Baseline - Epoch 50: Loss = 0.0045
# PYPL Baseline - Epoch 60: Loss = 0.0037
# PYPL Baseline - Epoch 70: Loss = 0.0033
# PYPL Baseline - Epoch 80: Loss = 0.0026
# PYPL Baseline - Epoch 90: Loss = 0.0025
# PYPL Baseline - Epoch 100: Loss = 0.0024
# PYPL Baseline - Epoch 110: Loss = 0.0025
# PYPL Baseline - Epoch 120: Loss = 0.0032
# PYPL Baseline - Epoch 130: Loss = 0.0025
# PYPL Baseline - Epoch 140: Loss = 0.0030
# PYPL Baseline - Epoch 150: Loss = 0.0024
# PYPL Baseline - Epoch 160: Loss = 0.0026
# PYPL Baseline - Epoch 170: Loss = 0.0022
# PYPL Baseline - Epoch 180: Loss = 0.0025
# PYPL Baseline - Epoch 190: Loss = 0.0022
# PYPL Baseline - Epoch 200: Loss = 0.0024
# PYPL Baseline - Epoch 210: Loss = 0.0022
# PYPL Baseline - Epoch 220: Loss = 0.0034
# PYPL Baseline - Epoch 230: Loss = 0.0022
# PYPL Baseline - Epoch 240: Loss = 0.0024
#
# Processing WMT
# Matched data points: 111
# WMT - Epoch 0: Loss = 0.3377
# WMT - Epoch 10: Loss = 0.0621
# WMT - Epoch 20: Loss = 0.0544
# WMT - Epoch 30: Loss = 0.0444
# WMT - Epoch 40: Loss = 0.0297
# WMT - Epoch 50: Loss = 0.0133
# WMT - Epoch 60: Loss = 0.0107
# WMT - Epoch 70: Loss = 0.0123
# WMT - Epoch 80: Loss = 0.0104
# WMT - Epoch 90: Loss = 0.0105
# WMT - Epoch 100: Loss = 0.0110
# WMT - Epoch 110: Loss = 0.0102
# WMT - Epoch 120: Loss = 0.0094
# WMT - Epoch 130: Loss = 0.0102
# WMT - Epoch 140: Loss = 0.0097
# WMT - Epoch 150: Loss = 0.0104
# WMT - Epoch 160: Loss = 0.0097
# WMT - Epoch 170: Loss = 0.0104
# WMT - Epoch 180: Loss = 0.0110
# WMT - Epoch 190: Loss = 0.0103
# WMT - Epoch 200: Loss = 0.0091
# WMT - Epoch 210: Loss = 0.0080
# WMT - Epoch 220: Loss = 0.0090
# WMT - Epoch 230: Loss = 0.0090
# WMT - Epoch 240: Loss = 0.0083
# WMT Baseline - Epoch 0: Loss = 0.1944
# WMT Baseline - Epoch 10: Loss = 0.0364
# WMT Baseline - Epoch 20: Loss = 0.0073
# WMT Baseline - Epoch 30: Loss = 0.0057
# WMT Baseline - Epoch 40: Loss = 0.0058
# WMT Baseline - Epoch 50: Loss = 0.0052
# WMT Baseline - Epoch 60: Loss = 0.0048
# WMT Baseline - Epoch 70: Loss = 0.0068
# WMT Baseline - Epoch 80: Loss = 0.0055
# WMT Baseline - Epoch 90: Loss = 0.0075
# WMT Baseline - Epoch 100: Loss = 0.0047
# WMT Baseline - Epoch 110: Loss = 0.0043
# WMT Baseline - Epoch 120: Loss = 0.0052
# WMT Baseline - Epoch 130: Loss = 0.0051
# WMT Baseline - Epoch 140: Loss = 0.0038
# WMT Baseline - Epoch 150: Loss = 0.0043
# WMT Baseline - Epoch 160: Loss = 0.0040
# WMT Baseline - Epoch 170: Loss = 0.0037
# WMT Baseline - Epoch 180: Loss = 0.0038
# WMT Baseline - Epoch 190: Loss = 0.0036
# WMT Baseline - Epoch 200: Loss = 0.0038
# WMT Baseline - Epoch 210: Loss = 0.0035
# WMT Baseline - Epoch 220: Loss = 0.0036
# WMT Baseline - Epoch 230: Loss = 0.0040
# WMT Baseline - Epoch 240: Loss = 0.0036
#
# Processing AMT
# Matched data points: 2
# Error processing AMT: Insufficient data points. Need at least 6 points, got 2
#
# Processing V
# Matched data points: 70
# V - Epoch 0: Loss = 0.4832
# V - Epoch 10: Loss = 0.1705
# V - Epoch 20: Loss = 0.0601
# V - Epoch 30: Loss = 0.0413
# V - Epoch 40: Loss = 0.0349
# V - Epoch 50: Loss = 0.0338
# V - Epoch 60: Loss = 0.0375
# V - Epoch 70: Loss = 0.0320
# V - Epoch 80: Loss = 0.0311
# V - Epoch 90: Loss = 0.0257
# V - Epoch 100: Loss = 0.0312
# V - Epoch 110: Loss = 0.0268
# V - Epoch 120: Loss = 0.0206
# V - Epoch 130: Loss = 0.0216
# V - Epoch 140: Loss = 0.0245
# V - Epoch 150: Loss = 0.0168
# V - Epoch 160: Loss = 0.0186
# V - Epoch 170: Loss = 0.0173
# V - Epoch 180: Loss = 0.0190
# V - Epoch 190: Loss = 0.0189
# V - Epoch 200: Loss = 0.0211
# V - Epoch 210: Loss = 0.0195
# V - Epoch 220: Loss = 0.0173
# V - Epoch 230: Loss = 0.0175
# V - Epoch 240: Loss = 0.0174
# V Baseline - Epoch 0: Loss = 0.6435
# V Baseline - Epoch 10: Loss = 0.0273
# V Baseline - Epoch 20: Loss = 0.0173
# V Baseline - Epoch 30: Loss = 0.0089
# V Baseline - Epoch 40: Loss = 0.0082
# V Baseline - Epoch 50: Loss = 0.0076
# V Baseline - Epoch 60: Loss = 0.0078
# V Baseline - Epoch 70: Loss = 0.0069
# V Baseline - Epoch 80: Loss = 0.0070
# V Baseline - Epoch 90: Loss = 0.0067
# V Baseline - Epoch 100: Loss = 0.0069
# V Baseline - Epoch 110: Loss = 0.0085
# V Baseline - Epoch 120: Loss = 0.0062
# V Baseline - Epoch 130: Loss = 0.0053
# V Baseline - Epoch 140: Loss = 0.0062
# V Baseline - Epoch 150: Loss = 0.0058
# V Baseline - Epoch 160: Loss = 0.0061
# V Baseline - Epoch 170: Loss = 0.0045
# V Baseline - Epoch 180: Loss = 0.0067
# V Baseline - Epoch 190: Loss = 0.0058
# V Baseline - Epoch 200: Loss = 0.0066
# V Baseline - Epoch 210: Loss = 0.0044
# V Baseline - Epoch 220: Loss = 0.0047
# V Baseline - Epoch 230: Loss = 0.0042
# V Baseline - Epoch 240: Loss = 0.0044
#
# Processing BABA
# Matched data points: 163
# BABA - Epoch 0: Loss = 0.1165
# BABA - Epoch 10: Loss = 0.0519
# BABA - Epoch 20: Loss = 0.0199
# BABA - Epoch 30: Loss = 0.0103
# BABA - Epoch 40: Loss = 0.0092
# BABA - Epoch 50: Loss = 0.0083
# BABA - Epoch 60: Loss = 0.0082
# BABA - Epoch 70: Loss = 0.0078
# BABA - Epoch 80: Loss = 0.0079
# BABA - Epoch 90: Loss = 0.0076
# BABA - Epoch 100: Loss = 0.0080
# BABA - Epoch 110: Loss = 0.0080
# BABA - Epoch 120: Loss = 0.0079
# BABA - Epoch 130: Loss = 0.0076
# BABA - Epoch 140: Loss = 0.0079
# BABA - Epoch 150: Loss = 0.0072
# BABA - Epoch 160: Loss = 0.0067
# BABA - Epoch 170: Loss = 0.0066
# BABA - Epoch 180: Loss = 0.0062
# BABA - Epoch 190: Loss = 0.0063
# BABA - Epoch 200: Loss = 0.0063
# BABA - Epoch 210: Loss = 0.0061
# BABA - Epoch 220: Loss = 0.0057
# BABA - Epoch 230: Loss = 0.0055
# BABA - Epoch 240: Loss = 0.0054
# BABA Baseline - Epoch 0: Loss = 0.1613
# BABA Baseline - Epoch 10: Loss = 0.0392
# BABA Baseline - Epoch 20: Loss = 0.0059
# BABA Baseline - Epoch 30: Loss = 0.0058
# BABA Baseline - Epoch 40: Loss = 0.0073
# BABA Baseline - Epoch 50: Loss = 0.0065
# BABA Baseline - Epoch 60: Loss = 0.0061
# BABA Baseline - Epoch 70: Loss = 0.0056
# BABA Baseline - Epoch 80: Loss = 0.0047
# BABA Baseline - Epoch 90: Loss = 0.0063
# BABA Baseline - Epoch 100: Loss = 0.0056
# BABA Baseline - Epoch 110: Loss = 0.0050
# BABA Baseline - Epoch 120: Loss = 0.0047
# BABA Baseline - Epoch 130: Loss = 0.0056
# BABA Baseline - Epoch 140: Loss = 0.0045
# BABA Baseline - Epoch 150: Loss = 0.0043
# BABA Baseline - Epoch 160: Loss = 0.0040
# BABA Baseline - Epoch 170: Loss = 0.0053
# BABA Baseline - Epoch 180: Loss = 0.0036
# BABA Baseline - Epoch 190: Loss = 0.0036
# BABA Baseline - Epoch 200: Loss = 0.0047
# BABA Baseline - Epoch 210: Loss = 0.0046
# BABA Baseline - Epoch 220: Loss = 0.0033
# BABA Baseline - Epoch 230: Loss = 0.0033
# BABA Baseline - Epoch 240: Loss = 0.0034
#
# Processing MSFT
# Matched data points: 196
# MSFT - Epoch 0: Loss = 0.4959
# MSFT - Epoch 10: Loss = 0.0467
# MSFT - Epoch 20: Loss = 0.0301
# MSFT - Epoch 30: Loss = 0.0095
# MSFT - Epoch 40: Loss = 0.0065
# MSFT - Epoch 50: Loss = 0.0066
# MSFT - Epoch 60: Loss = 0.0068
# MSFT - Epoch 70: Loss = 0.0062
# MSFT - Epoch 80: Loss = 0.0061
# MSFT - Epoch 90: Loss = 0.0059
# MSFT - Epoch 100: Loss = 0.0062
# MSFT - Epoch 110: Loss = 0.0053
# MSFT - Epoch 120: Loss = 0.0059
# MSFT - Epoch 130: Loss = 0.0055
# MSFT - Epoch 140: Loss = 0.0048
# MSFT - Epoch 150: Loss = 0.0052
# MSFT - Epoch 160: Loss = 0.0055
# MSFT - Epoch 170: Loss = 0.0052
# MSFT - Epoch 180: Loss = 0.0051
# MSFT - Epoch 190: Loss = 0.0051
# MSFT - Epoch 200: Loss = 0.0057
# MSFT - Epoch 210: Loss = 0.0047
# MSFT - Epoch 220: Loss = 0.0045
# MSFT - Epoch 230: Loss = 0.0044
# MSFT - Epoch 240: Loss = 0.0047
# MSFT Baseline - Epoch 0: Loss = 0.3138
# MSFT Baseline - Epoch 10: Loss = 0.0342
# MSFT Baseline - Epoch 20: Loss = 0.0082
# MSFT Baseline - Epoch 30: Loss = 0.0055
# MSFT Baseline - Epoch 40: Loss = 0.0059
# MSFT Baseline - Epoch 50: Loss = 0.0055
# MSFT Baseline - Epoch 60: Loss = 0.0050
# MSFT Baseline - Epoch 70: Loss = 0.0040
# MSFT Baseline - Epoch 80: Loss = 0.0049
# MSFT Baseline - Epoch 90: Loss = 0.0049
# MSFT Baseline - Epoch 100: Loss = 0.0042
# MSFT Baseline - Epoch 110: Loss = 0.0040
# MSFT Baseline - Epoch 120: Loss = 0.0045
# MSFT Baseline - Epoch 130: Loss = 0.0049
# MSFT Baseline - Epoch 140: Loss = 0.0048
# MSFT Baseline - Epoch 150: Loss = 0.0038
# MSFT Baseline - Epoch 160: Loss = 0.0051
# MSFT Baseline - Epoch 170: Loss = 0.0038
# MSFT Baseline - Epoch 180: Loss = 0.0041
# MSFT Baseline - Epoch 190: Loss = 0.0049
# MSFT Baseline - Epoch 200: Loss = 0.0039
# MSFT Baseline - Epoch 210: Loss = 0.0043
# MSFT Baseline - Epoch 220: Loss = 0.0037
# MSFT Baseline - Epoch 230: Loss = 0.0052
# MSFT Baseline - Epoch 240: Loss = 0.0049
#
# Processing BKNG
# Matched data points: 19
# BKNG - Epoch 0: Loss = 0.6438
# BKNG - Epoch 10: Loss = 0.4746
# BKNG - Epoch 20: Loss = 0.3048
# BKNG - Epoch 30: Loss = 0.1366
# BKNG - Epoch 40: Loss = 0.0605
# BKNG - Epoch 50: Loss = 0.0760
# BKNG - Epoch 60: Loss = 0.0652
# BKNG - Epoch 70: Loss = 0.0619
# BKNG - Epoch 80: Loss = 0.0606
# BKNG - Epoch 90: Loss = 0.0648
# BKNG - Epoch 100: Loss = 0.0566
# BKNG - Epoch 110: Loss = 0.0588
# BKNG - Epoch 120: Loss = 0.0546
# BKNG - Epoch 130: Loss = 0.0564
# BKNG - Epoch 140: Loss = 0.0546
# BKNG - Epoch 150: Loss = 0.0525
# BKNG - Epoch 160: Loss = 0.0492
# BKNG - Epoch 170: Loss = 0.0501
# BKNG - Epoch 180: Loss = 0.0529
# BKNG - Epoch 190: Loss = 0.0534
# BKNG - Epoch 200: Loss = 0.0436
# BKNG - Epoch 210: Loss = 0.0466
# BKNG - Epoch 220: Loss = 0.0416
# BKNG - Epoch 230: Loss = 0.0459
# BKNG - Epoch 240: Loss = 0.0456
# BKNG Baseline - Epoch 0: Loss = 0.5867
# BKNG Baseline - Epoch 10: Loss = 0.0359
# BKNG Baseline - Epoch 20: Loss = 0.0104
# BKNG Baseline - Epoch 30: Loss = 0.0090
# BKNG Baseline - Epoch 40: Loss = 0.0075
# BKNG Baseline - Epoch 50: Loss = 0.0069
# BKNG Baseline - Epoch 60: Loss = 0.0065
# BKNG Baseline - Epoch 70: Loss = 0.0066
# BKNG Baseline - Epoch 80: Loss = 0.0061
# BKNG Baseline - Epoch 90: Loss = 0.0061
# BKNG Baseline - Epoch 100: Loss = 0.0058
# BKNG Baseline - Epoch 110: Loss = 0.0064
# BKNG Baseline - Epoch 120: Loss = 0.0065
# BKNG Baseline - Epoch 130: Loss = 0.0050
# BKNG Baseline - Epoch 140: Loss = 0.0052
# BKNG Baseline - Epoch 150: Loss = 0.0049
# BKNG Baseline - Epoch 160: Loss = 0.0055
# BKNG Baseline - Epoch 170: Loss = 0.0052
# BKNG Baseline - Epoch 180: Loss = 0.0050
# BKNG Baseline - Epoch 190: Loss = 0.0044
# BKNG Baseline - Epoch 200: Loss = 0.0044
# BKNG Baseline - Epoch 210: Loss = 0.0053
# BKNG Baseline - Epoch 220: Loss = 0.0045
# BKNG Baseline - Epoch 230: Loss = 0.0039
# BKNG Baseline - Epoch 240: Loss = 0.0038
#
# Processing DIS
# Matched data points: 178
# DIS - Epoch 0: Loss = 0.0657
# DIS - Epoch 10: Loss = 0.0288
# DIS - Epoch 20: Loss = 0.0072
# DIS - Epoch 30: Loss = 0.0047
# DIS - Epoch 40: Loss = 0.0042
# DIS - Epoch 50: Loss = 0.0049
# DIS - Epoch 60: Loss = 0.0040
# DIS - Epoch 70: Loss = 0.0042
# DIS - Epoch 80: Loss = 0.0042
# DIS - Epoch 90: Loss = 0.0045
# DIS - Epoch 100: Loss = 0.0041
# DIS - Epoch 110: Loss = 0.0035
# DIS - Epoch 120: Loss = 0.0042
# DIS - Epoch 130: Loss = 0.0036
# DIS - Epoch 140: Loss = 0.0034
# DIS - Epoch 150: Loss = 0.0031
# DIS - Epoch 160: Loss = 0.0035
# DIS - Epoch 170: Loss = 0.0038
# DIS - Epoch 180: Loss = 0.0032
# DIS - Epoch 190: Loss = 0.0032
# DIS - Epoch 200: Loss = 0.0033
# DIS - Epoch 210: Loss = 0.0030
# DIS - Epoch 220: Loss = 0.0028
# DIS - Epoch 230: Loss = 0.0029
# DIS - Epoch 240: Loss = 0.0026
# DIS Baseline - Epoch 0: Loss = 0.2160
# DIS Baseline - Epoch 10: Loss = 0.0266
# DIS Baseline - Epoch 20: Loss = 0.0045
# DIS Baseline - Epoch 30: Loss = 0.0044
# DIS Baseline - Epoch 40: Loss = 0.0041
# DIS Baseline - Epoch 50: Loss = 0.0041
# DIS Baseline - Epoch 60: Loss = 0.0042
# DIS Baseline - Epoch 70: Loss = 0.0036
# DIS Baseline - Epoch 80: Loss = 0.0044
# DIS Baseline - Epoch 90: Loss = 0.0042
# DIS Baseline - Epoch 100: Loss = 0.0036
# DIS Baseline - Epoch 110: Loss = 0.0033
# DIS Baseline - Epoch 120: Loss = 0.0032
# DIS Baseline - Epoch 130: Loss = 0.0036
# DIS Baseline - Epoch 140: Loss = 0.0033
# DIS Baseline - Epoch 150: Loss = 0.0042
# DIS Baseline - Epoch 160: Loss = 0.0030
# DIS Baseline - Epoch 170: Loss = 0.0032
# DIS Baseline - Epoch 180: Loss = 0.0026
# DIS Baseline - Epoch 190: Loss = 0.0028
# DIS Baseline - Epoch 200: Loss = 0.0026
# DIS Baseline - Epoch 210: Loss = 0.0025
# DIS Baseline - Epoch 220: Loss = 0.0031
# DIS Baseline - Epoch 230: Loss = 0.0024
# DIS Baseline - Epoch 240: Loss = 0.0027
#
# Processing TM
# Matched data points: 1
# Error processing TM: Insufficient data points. Need at least 6 points, got 1
#
# Processing AMZN
# Matched data points: 212
# AMZN - Epoch 0: Loss = 0.2895
# AMZN - Epoch 10: Loss = 0.0574
# AMZN - Epoch 20: Loss = 0.0066
# AMZN - Epoch 30: Loss = 0.0057
# AMZN - Epoch 40: Loss = 0.0053
# AMZN - Epoch 50: Loss = 0.0047
# AMZN - Epoch 60: Loss = 0.0041
# AMZN - Epoch 70: Loss = 0.0032
# AMZN - Epoch 80: Loss = 0.0037
# AMZN - Epoch 90: Loss = 0.0040
# AMZN - Epoch 100: Loss = 0.0033
# AMZN - Epoch 110: Loss = 0.0033
# AMZN - Epoch 120: Loss = 0.0033
# AMZN - Epoch 130: Loss = 0.0036
# AMZN - Epoch 140: Loss = 0.0041
# AMZN - Epoch 150: Loss = 0.0032
# AMZN - Epoch 160: Loss = 0.0032
# AMZN - Epoch 170: Loss = 0.0034
# AMZN - Epoch 180: Loss = 0.0036
# AMZN - Epoch 190: Loss = 0.0033
# AMZN - Epoch 200: Loss = 0.0034
# AMZN - Epoch 210: Loss = 0.0038
# AMZN - Epoch 220: Loss = 0.0036
# AMZN - Epoch 230: Loss = 0.0027
# AMZN - Epoch 240: Loss = 0.0030
# AMZN Baseline - Epoch 0: Loss = 0.2473
# AMZN Baseline - Epoch 10: Loss = 0.0505
# AMZN Baseline - Epoch 20: Loss = 0.0064
# AMZN Baseline - Epoch 30: Loss = 0.0048
# AMZN Baseline - Epoch 40: Loss = 0.0035
# AMZN Baseline - Epoch 50: Loss = 0.0033
# AMZN Baseline - Epoch 60: Loss = 0.0029
# AMZN Baseline - Epoch 70: Loss = 0.0037
# AMZN Baseline - Epoch 80: Loss = 0.0039
# AMZN Baseline - Epoch 90: Loss = 0.0029
# AMZN Baseline - Epoch 100: Loss = 0.0026
# AMZN Baseline - Epoch 110: Loss = 0.0029
# AMZN Baseline - Epoch 120: Loss = 0.0024
# AMZN Baseline - Epoch 130: Loss = 0.0027
# AMZN Baseline - Epoch 140: Loss = 0.0026
# AMZN Baseline - Epoch 150: Loss = 0.0032
# AMZN Baseline - Epoch 160: Loss = 0.0032
# AMZN Baseline - Epoch 170: Loss = 0.0032
# AMZN Baseline - Epoch 180: Loss = 0.0024
# AMZN Baseline - Epoch 190: Loss = 0.0027
# AMZN Baseline - Epoch 200: Loss = 0.0030
# AMZN Baseline - Epoch 210: Loss = 0.0031
# AMZN Baseline - Epoch 220: Loss = 0.0024
# AMZN Baseline - Epoch 230: Loss = 0.0025
# AMZN Baseline - Epoch 240: Loss = 0.0022
#
# Processing AAPL
# Matched data points: 252
# AAPL - Epoch 0: Loss = 0.2321
# AAPL - Epoch 10: Loss = 0.0487
# AAPL - Epoch 20: Loss = 0.0046
# AAPL - Epoch 30: Loss = 0.0044
# AAPL - Epoch 40: Loss = 0.0024
# AAPL - Epoch 50: Loss = 0.0031
# AAPL - Epoch 60: Loss = 0.0024
# AAPL - Epoch 70: Loss = 0.0030
# AAPL - Epoch 80: Loss = 0.0023
# AAPL - Epoch 90: Loss = 0.0023
# AAPL - Epoch 100: Loss = 0.0027
# AAPL - Epoch 110: Loss = 0.0024
# AAPL - Epoch 120: Loss = 0.0023
# AAPL - Epoch 130: Loss = 0.0020
# AAPL - Epoch 140: Loss = 0.0022
# AAPL - Epoch 150: Loss = 0.0021
# AAPL - Epoch 160: Loss = 0.0022
# AAPL - Epoch 170: Loss = 0.0022
# AAPL - Epoch 180: Loss = 0.0022
# AAPL - Epoch 190: Loss = 0.0021
# AAPL - Epoch 200: Loss = 0.0020
# AAPL - Epoch 210: Loss = 0.0023
# AAPL - Epoch 220: Loss = 0.0021
# AAPL - Epoch 230: Loss = 0.0023
# AAPL - Epoch 240: Loss = 0.0026
# AAPL Baseline - Epoch 0: Loss = 0.4111
# AAPL Baseline - Epoch 10: Loss = 0.0525
# AAPL Baseline - Epoch 20: Loss = 0.0096
# AAPL Baseline - Epoch 30: Loss = 0.0064
# AAPL Baseline - Epoch 40: Loss = 0.0045
# AAPL Baseline - Epoch 50: Loss = 0.0046
# AAPL Baseline - Epoch 60: Loss = 0.0038
# AAPL Baseline - Epoch 70: Loss = 0.0035
# AAPL Baseline - Epoch 80: Loss = 0.0030
# AAPL Baseline - Epoch 90: Loss = 0.0037
# AAPL Baseline - Epoch 100: Loss = 0.0033
# AAPL Baseline - Epoch 110: Loss = 0.0029
# AAPL Baseline - Epoch 120: Loss = 0.0030
# AAPL Baseline - Epoch 130: Loss = 0.0028
# AAPL Baseline - Epoch 140: Loss = 0.0031
# AAPL Baseline - Epoch 150: Loss = 0.0023
# AAPL Baseline - Epoch 160: Loss = 0.0028
# AAPL Baseline - Epoch 170: Loss = 0.0025
# AAPL Baseline - Epoch 180: Loss = 0.0035
# AAPL Baseline - Epoch 190: Loss = 0.0023
# AAPL Baseline - Epoch 200: Loss = 0.0026
# AAPL Baseline - Epoch 210: Loss = 0.0023
# AAPL Baseline - Epoch 220: Loss = 0.0026
# AAPL Baseline - Epoch 230: Loss = 0.0022
# AAPL Baseline - Epoch 240: Loss = 0.0025
#
# Processing JPM
# Matched data points: 60
# JPM - Epoch 0: Loss = 0.0753
# JPM - Epoch 10: Loss = 0.0203
# JPM - Epoch 20: Loss = 0.0209
# JPM - Epoch 30: Loss = 0.0199
# JPM - Epoch 40: Loss = 0.0173
# JPM - Epoch 50: Loss = 0.0145
# JPM - Epoch 60: Loss = 0.0156
# JPM - Epoch 70: Loss = 0.0184
# JPM - Epoch 80: Loss = 0.0156
# JPM - Epoch 90: Loss = 0.0155
# JPM - Epoch 100: Loss = 0.0155
# JPM - Epoch 110: Loss = 0.0177
# JPM - Epoch 120: Loss = 0.0145
# JPM - Epoch 130: Loss = 0.0143
# JPM - Epoch 140: Loss = 0.0130
# JPM - Epoch 150: Loss = 0.0155
# JPM - Epoch 160: Loss = 0.0118
# JPM - Epoch 170: Loss = 0.0123
# JPM - Epoch 180: Loss = 0.0138
# JPM - Epoch 190: Loss = 0.0074
# JPM - Epoch 200: Loss = 0.0099
# JPM - Epoch 210: Loss = 0.0097
# JPM - Epoch 220: Loss = 0.0086
# JPM - Epoch 230: Loss = 0.0093
# JPM - Epoch 240: Loss = 0.0088
# JPM Baseline - Epoch 0: Loss = 0.1695
# JPM Baseline - Epoch 10: Loss = 0.0403
# JPM Baseline - Epoch 20: Loss = 0.0076
# JPM Baseline - Epoch 30: Loss = 0.0061
# JPM Baseline - Epoch 40: Loss = 0.0055
# JPM Baseline - Epoch 50: Loss = 0.0061
# JPM Baseline - Epoch 60: Loss = 0.0058
# JPM Baseline - Epoch 70: Loss = 0.0061
# JPM Baseline - Epoch 80: Loss = 0.0055
# JPM Baseline - Epoch 90: Loss = 0.0075
# JPM Baseline - Epoch 100: Loss = 0.0063
# JPM Baseline - Epoch 110: Loss = 0.0051
# JPM Baseline - Epoch 120: Loss = 0.0054
# JPM Baseline - Epoch 130: Loss = 0.0078
# JPM Baseline - Epoch 140: Loss = 0.0053
# JPM Baseline - Epoch 150: Loss = 0.0044
# JPM Baseline - Epoch 160: Loss = 0.0046
# JPM Baseline - Epoch 170: Loss = 0.0040
# JPM Baseline - Epoch 180: Loss = 0.0044
# JPM Baseline - Epoch 190: Loss = 0.0043
# JPM Baseline - Epoch 200: Loss = 0.0042
# JPM Baseline - Epoch 210: Loss = 0.0040
# JPM Baseline - Epoch 220: Loss = 0.0049
# JPM Baseline - Epoch 230: Loss = 0.0037
# JPM Baseline - Epoch 240: Loss = 0.0035
#
# Processing GOOGL
# Matched data points: 49
# GOOGL - Epoch 0: Loss = 0.1435
# GOOGL - Epoch 10: Loss = 0.0831
# GOOGL - Epoch 20: Loss = 0.0386
# GOOGL - Epoch 30: Loss = 0.0414
# GOOGL - Epoch 40: Loss = 0.0307
# GOOGL - Epoch 50: Loss = 0.0407
# GOOGL - Epoch 60: Loss = 0.0322
# GOOGL - Epoch 70: Loss = 0.0373
# GOOGL - Epoch 80: Loss = 0.0206
# GOOGL - Epoch 90: Loss = 0.0500
# GOOGL - Epoch 100: Loss = 0.0387
# GOOGL - Epoch 110: Loss = 0.0945
# GOOGL - Epoch 120: Loss = 0.0244
# GOOGL - Epoch 130: Loss = 0.0361
# GOOGL - Epoch 140: Loss = 0.0181
# GOOGL - Epoch 150: Loss = 0.0681
# GOOGL - Epoch 160: Loss = 0.0175
# GOOGL - Epoch 170: Loss = 0.0570
# GOOGL - Epoch 180: Loss = 0.0146
# GOOGL - Epoch 190: Loss = 0.0191
# GOOGL - Epoch 200: Loss = 0.0171
# GOOGL - Epoch 210: Loss = 0.0226
# GOOGL - Epoch 220: Loss = 0.0187
# GOOGL - Epoch 230: Loss = 0.0156
# GOOGL - Epoch 240: Loss = 0.0159
# GOOGL Baseline - Epoch 0: Loss = 0.4449
# GOOGL Baseline - Epoch 10: Loss = 0.0368
# GOOGL Baseline - Epoch 20: Loss = 0.0100
# GOOGL Baseline - Epoch 30: Loss = 0.0059
# GOOGL Baseline - Epoch 40: Loss = 0.0063
# GOOGL Baseline - Epoch 50: Loss = 0.0049
# GOOGL Baseline - Epoch 60: Loss = 0.0045
# GOOGL Baseline - Epoch 70: Loss = 0.0046
# GOOGL Baseline - Epoch 80: Loss = 0.0055
# GOOGL Baseline - Epoch 90: Loss = 0.0056
# GOOGL Baseline - Epoch 100: Loss = 0.0045
# GOOGL Baseline - Epoch 110: Loss = 0.0048
# GOOGL Baseline - Epoch 120: Loss = 0.0041
# GOOGL Baseline - Epoch 130: Loss = 0.0038
# GOOGL Baseline - Epoch 140: Loss = 0.0048
# GOOGL Baseline - Epoch 150: Loss = 0.0039
# GOOGL Baseline - Epoch 160: Loss = 0.0047
# GOOGL Baseline - Epoch 170: Loss = 0.0043
# GOOGL Baseline - Epoch 180: Loss = 0.0044
# GOOGL Baseline - Epoch 190: Loss = 0.0033
# GOOGL Baseline - Epoch 200: Loss = 0.0054
# GOOGL Baseline - Epoch 210: Loss = 0.0059
# GOOGL Baseline - Epoch 220: Loss = 0.0048
# GOOGL Baseline - Epoch 230: Loss = 0.0038
# GOOGL Baseline - Epoch 240: Loss = 0.0035
#
# Processing MA
# Matched data points: 30
# MA - Epoch 0: Loss = 0.1971
# MA - Epoch 10: Loss = 0.1208
# MA - Epoch 20: Loss = 0.0635
# MA - Epoch 30: Loss = 0.0545
# MA - Epoch 40: Loss = 0.0511
# MA - Epoch 50: Loss = 0.0531
# MA - Epoch 60: Loss = 0.0517
# MA - Epoch 70: Loss = 0.0497
# MA - Epoch 80: Loss = 0.0434
# MA - Epoch 90: Loss = 0.0411
# MA - Epoch 100: Loss = 0.0419
# MA - Epoch 110: Loss = 0.0378
# MA - Epoch 120: Loss = 0.0368
# MA - Epoch 130: Loss = 0.0291
# MA - Epoch 140: Loss = 0.0332
# MA - Epoch 150: Loss = 0.0305
# MA - Epoch 160: Loss = 0.0377
# MA - Epoch 170: Loss = 0.0219
# MA - Epoch 180: Loss = 0.0299
# MA - Epoch 190: Loss = 0.0230
# MA - Epoch 200: Loss = 0.0200
# MA - Epoch 210: Loss = 0.0218
# MA - Epoch 220: Loss = 0.0210
# MA - Epoch 230: Loss = 0.0144
# MA - Epoch 240: Loss = 0.0184
# MA Baseline - Epoch 0: Loss = 0.4934
# MA Baseline - Epoch 10: Loss = 0.0346
# MA Baseline - Epoch 20: Loss = 0.0272
# MA Baseline - Epoch 30: Loss = 0.0109
# MA Baseline - Epoch 40: Loss = 0.0086
# MA Baseline - Epoch 50: Loss = 0.0088
# MA Baseline - Epoch 60: Loss = 0.0067
# MA Baseline - Epoch 70: Loss = 0.0097
# MA Baseline - Epoch 80: Loss = 0.0060
# MA Baseline - Epoch 90: Loss = 0.0059
# MA Baseline - Epoch 100: Loss = 0.0069
# MA Baseline - Epoch 110: Loss = 0.0070
# MA Baseline - Epoch 120: Loss = 0.0060
# MA Baseline - Epoch 130: Loss = 0.0071
# MA Baseline - Epoch 140: Loss = 0.0059
# MA Baseline - Epoch 150: Loss = 0.0053
# MA Baseline - Epoch 160: Loss = 0.0056
# MA Baseline - Epoch 170: Loss = 0.0065
# MA Baseline - Epoch 180: Loss = 0.0046
# MA Baseline - Epoch 190: Loss = 0.0057
# MA Baseline - Epoch 200: Loss = 0.0044
# MA Baseline - Epoch 210: Loss = 0.0045
# MA Baseline - Epoch 220: Loss = 0.0037
# MA Baseline - Epoch 230: Loss = 0.0041
# MA Baseline - Epoch 240: Loss = 0.0036
#
# Processing GOOG
# Matched data points: 37
# GOOG - Epoch 0: Loss = 0.4436
# GOOG - Epoch 10: Loss = 0.3110
# GOOG - Epoch 20: Loss = 0.2004
# GOOG - Epoch 30: Loss = 0.1076
# GOOG - Epoch 40: Loss = 0.0752
# GOOG - Epoch 50: Loss = 0.0715
# GOOG - Epoch 60: Loss = 0.0695
# GOOG - Epoch 70: Loss = 0.0683
# GOOG - Epoch 80: Loss = 0.0693
# GOOG - Epoch 90: Loss = 0.0652
# GOOG - Epoch 100: Loss = 0.0590
# GOOG - Epoch 110: Loss = 0.0497
# GOOG - Epoch 120: Loss = 0.0465
# GOOG - Epoch 130: Loss = 0.0455
# GOOG - Epoch 140: Loss = 0.0405
# GOOG - Epoch 150: Loss = 0.0328
# GOOG - Epoch 160: Loss = 0.0280
# GOOG - Epoch 170: Loss = 0.0244
# GOOG - Epoch 180: Loss = 0.0350
# GOOG - Epoch 190: Loss = 0.0315
# GOOG - Epoch 200: Loss = 0.0309
# GOOG - Epoch 210: Loss = 0.0269
# GOOG - Epoch 220: Loss = 0.0205
# GOOG - Epoch 230: Loss = 0.0225
# GOOG - Epoch 240: Loss = 0.0227
# GOOG Baseline - Epoch 0: Loss = 0.6754
# GOOG Baseline - Epoch 10: Loss = 0.0350
# GOOG Baseline - Epoch 20: Loss = 0.0214
# GOOG Baseline - Epoch 30: Loss = 0.0070
# GOOG Baseline - Epoch 40: Loss = 0.0051
# GOOG Baseline - Epoch 50: Loss = 0.0050
# GOOG Baseline - Epoch 60: Loss = 0.0050
# GOOG Baseline - Epoch 70: Loss = 0.0052
# GOOG Baseline - Epoch 80: Loss = 0.0047
# GOOG Baseline - Epoch 90: Loss = 0.0043
# GOOG Baseline - Epoch 100: Loss = 0.0042
# GOOG Baseline - Epoch 110: Loss = 0.0040
# GOOG Baseline - Epoch 120: Loss = 0.0038
# GOOG Baseline - Epoch 130: Loss = 0.0040
# GOOG Baseline - Epoch 140: Loss = 0.0046
# GOOG Baseline - Epoch 150: Loss = 0.0040
# GOOG Baseline - Epoch 160: Loss = 0.0037
# GOOG Baseline - Epoch 170: Loss = 0.0038
# GOOG Baseline - Epoch 180: Loss = 0.0042
# GOOG Baseline - Epoch 190: Loss = 0.0039
# GOOG Baseline - Epoch 200: Loss = 0.0037
# GOOG Baseline - Epoch 210: Loss = 0.0037
# GOOG Baseline - Epoch 220: Loss = 0.0035
# GOOG Baseline - Epoch 230: Loss = 0.0031
# GOOG Baseline - Epoch 240: Loss = 0.0040
#
# Processing MCD
# Matched data points: 53
# MCD - Epoch 0: Loss = 0.3316
# MCD - Epoch 10: Loss = 0.0976
# MCD - Epoch 20: Loss = 0.0432
# MCD - Epoch 30: Loss = 0.0392
# MCD - Epoch 40: Loss = 0.0388
# MCD - Epoch 50: Loss = 0.0733
# MCD - Epoch 60: Loss = 0.0300
# MCD - Epoch 70: Loss = 0.0639
# MCD - Epoch 80: Loss = 0.0214
# MCD - Epoch 90: Loss = 0.0273
# MCD - Epoch 100: Loss = 0.0173
# MCD - Epoch 110: Loss = 0.0146
# MCD - Epoch 120: Loss = 0.0142
# MCD - Epoch 130: Loss = 0.0169
# MCD - Epoch 140: Loss = 0.0180
# MCD - Epoch 150: Loss = 0.0143
# MCD - Epoch 160: Loss = 0.0545
# MCD - Epoch 170: Loss = 0.0152
# MCD - Epoch 180: Loss = 0.0129
# MCD - Epoch 190: Loss = 0.0170
# MCD - Epoch 200: Loss = 0.0154
# MCD - Epoch 210: Loss = 0.0135
# MCD - Epoch 220: Loss = 0.0140
# MCD - Epoch 230: Loss = 0.0573
# MCD - Epoch 240: Loss = 0.0156
# MCD Baseline - Epoch 0: Loss = 0.2322
# MCD Baseline - Epoch 10: Loss = 0.0267
# MCD Baseline - Epoch 20: Loss = 0.0077
# MCD Baseline - Epoch 30: Loss = 0.0063
# MCD Baseline - Epoch 40: Loss = 0.0070
# MCD Baseline - Epoch 50: Loss = 0.0053
# MCD Baseline - Epoch 60: Loss = 0.0047
# MCD Baseline - Epoch 70: Loss = 0.0049
# MCD Baseline - Epoch 80: Loss = 0.0046
# MCD Baseline - Epoch 90: Loss = 0.0047
# MCD Baseline - Epoch 100: Loss = 0.0044
# MCD Baseline - Epoch 110: Loss = 0.0043
# MCD Baseline - Epoch 120: Loss = 0.0059
# MCD Baseline - Epoch 130: Loss = 0.0050
# MCD Baseline - Epoch 140: Loss = 0.0048
# MCD Baseline - Epoch 150: Loss = 0.0042
# MCD Baseline - Epoch 160: Loss = 0.0040
# MCD Baseline - Epoch 170: Loss = 0.0040
# MCD Baseline - Epoch 180: Loss = 0.0047
# MCD Baseline - Epoch 190: Loss = 0.0042
# MCD Baseline - Epoch 200: Loss = 0.0033
# MCD Baseline - Epoch 210: Loss = 0.0032
# MCD Baseline - Epoch 220: Loss = 0.0029
# MCD Baseline - Epoch 230: Loss = 0.0031
# MCD Baseline - Epoch 240: Loss = 0.0029
#
# Processing UPS
# Matched data points: 28
# UPS - Epoch 0: Loss = 0.4591
# UPS - Epoch 10: Loss = 0.3429
# UPS - Epoch 20: Loss = 0.2102
# UPS - Epoch 30: Loss = 0.0738
# UPS - Epoch 40: Loss = 0.0609
# UPS - Epoch 50: Loss = 0.0386
# UPS - Epoch 60: Loss = 0.0376
# UPS - Epoch 70: Loss = 0.0339
# UPS - Epoch 80: Loss = 0.0312
# UPS - Epoch 90: Loss = 0.0245
# UPS - Epoch 100: Loss = 0.0229
# UPS - Epoch 110: Loss = 0.0177
# UPS - Epoch 120: Loss = 0.0177
# UPS - Epoch 130: Loss = 0.0170
# UPS - Epoch 140: Loss = 0.0192
# UPS - Epoch 150: Loss = 0.0174
# UPS - Epoch 160: Loss = 0.0160
# UPS - Epoch 170: Loss = 0.0155
# UPS - Epoch 180: Loss = 0.0140
# UPS - Epoch 190: Loss = 0.0162
# UPS - Epoch 200: Loss = 0.0139
# UPS - Epoch 210: Loss = 0.0109
# UPS - Epoch 220: Loss = 0.0115
# UPS - Epoch 230: Loss = 0.0116
# UPS - Epoch 240: Loss = 0.0143
# UPS Baseline - Epoch 0: Loss = 0.3719
# UPS Baseline - Epoch 10: Loss = 0.0472
# UPS Baseline - Epoch 20: Loss = 0.0057
# UPS Baseline - Epoch 30: Loss = 0.0047
# UPS Baseline - Epoch 40: Loss = 0.0041
# UPS Baseline - Epoch 50: Loss = 0.0030
# UPS Baseline - Epoch 60: Loss = 0.0034
# UPS Baseline - Epoch 70: Loss = 0.0026
# UPS Baseline - Epoch 80: Loss = 0.0027
# UPS Baseline - Epoch 90: Loss = 0.0026
# UPS Baseline - Epoch 100: Loss = 0.0040
# UPS Baseline - Epoch 110: Loss = 0.0026
# UPS Baseline - Epoch 120: Loss = 0.0022
# UPS Baseline - Epoch 130: Loss = 0.0030
# UPS Baseline - Epoch 140: Loss = 0.0026
# UPS Baseline - Epoch 150: Loss = 0.0029
# UPS Baseline - Epoch 160: Loss = 0.0021
# UPS Baseline - Epoch 170: Loss = 0.0023
# UPS Baseline - Epoch 180: Loss = 0.0027
# UPS Baseline - Epoch 190: Loss = 0.0034
# UPS Baseline - Epoch 200: Loss = 0.0023
# UPS Baseline - Epoch 210: Loss = 0.0025
# UPS Baseline - Epoch 220: Loss = 0.0024
# UPS Baseline - Epoch 230: Loss = 0.0024
# UPS Baseline - Epoch 240: Loss = 0.0022
#
# Processing LOW
# Matched data points: 26
# LOW - Epoch 0: Loss = 0.6872
# LOW - Epoch 10: Loss = 0.5182
# LOW - Epoch 20: Loss = 0.3380
# LOW - Epoch 30: Loss = 0.1393
# LOW - Epoch 40: Loss = 0.0201
# LOW - Epoch 50: Loss = 0.0348
# LOW - Epoch 60: Loss = 0.0178
# LOW - Epoch 70: Loss = 0.0213
# LOW - Epoch 80: Loss = 0.0158
# LOW - Epoch 90: Loss = 0.0164
# LOW - Epoch 100: Loss = 0.0175
# LOW - Epoch 110: Loss = 0.0182
# LOW - Epoch 120: Loss = 0.0163
# LOW - Epoch 130: Loss = 0.0150
# LOW - Epoch 140: Loss = 0.0142
# LOW - Epoch 150: Loss = 0.0132
# LOW - Epoch 160: Loss = 0.0143
# LOW - Epoch 170: Loss = 0.0132
# LOW - Epoch 180: Loss = 0.0112
# LOW - Epoch 190: Loss = 0.0104
# LOW - Epoch 200: Loss = 0.0088
# LOW - Epoch 210: Loss = 0.0105
# LOW - Epoch 220: Loss = 0.0072
# LOW - Epoch 230: Loss = 0.0078
# LOW - Epoch 240: Loss = 0.0057
# LOW Baseline - Epoch 0: Loss = 0.5847
# LOW Baseline - Epoch 10: Loss = 0.0364
# LOW Baseline - Epoch 20: Loss = 0.0128
# LOW Baseline - Epoch 30: Loss = 0.0054
# LOW Baseline - Epoch 40: Loss = 0.0053
# LOW Baseline - Epoch 50: Loss = 0.0039
# LOW Baseline - Epoch 60: Loss = 0.0034
# LOW Baseline - Epoch 70: Loss = 0.0039
# LOW Baseline - Epoch 80: Loss = 0.0036
# LOW Baseline - Epoch 90: Loss = 0.0039
# LOW Baseline - Epoch 100: Loss = 0.0039
# LOW Baseline - Epoch 110: Loss = 0.0035
# LOW Baseline - Epoch 120: Loss = 0.0031
# LOW Baseline - Epoch 130: Loss = 0.0027
# LOW Baseline - Epoch 140: Loss = 0.0032
# LOW Baseline - Epoch 150: Loss = 0.0033
# LOW Baseline - Epoch 160: Loss = 0.0031
# LOW Baseline - Epoch 170: Loss = 0.0030
# LOW Baseline - Epoch 180: Loss = 0.0037
# LOW Baseline - Epoch 190: Loss = 0.0029
# LOW Baseline - Epoch 200: Loss = 0.0043
# LOW Baseline - Epoch 210: Loss = 0.0028
# LOW Baseline - Epoch 220: Loss = 0.0036
# LOW Baseline - Epoch 230: Loss = 0.0029
# LOW Baseline - Epoch 240: Loss = 0.0025
#
# Processing XOM
# Matched data points: 84
# XOM - Epoch 0: Loss = 0.0859
# XOM - Epoch 10: Loss = 0.0216
# XOM - Epoch 20: Loss = 0.0211
# XOM - Epoch 30: Loss = 0.0198
# XOM - Epoch 40: Loss = 0.0182
# XOM - Epoch 50: Loss = 0.0155
# XOM - Epoch 60: Loss = 0.0109
# XOM - Epoch 70: Loss = 0.0090
# XOM - Epoch 80: Loss = 0.0087
# XOM - Epoch 90: Loss = 0.0087
# XOM - Epoch 100: Loss = 0.0085
# XOM - Epoch 110: Loss = 0.0088
# XOM - Epoch 120: Loss = 0.0072
# XOM - Epoch 130: Loss = 0.0068
# XOM - Epoch 140: Loss = 0.0078
# XOM - Epoch 150: Loss = 0.0063
# XOM - Epoch 160: Loss = 0.0063
# XOM - Epoch 170: Loss = 0.0062
# XOM - Epoch 180: Loss = 0.0063
# XOM - Epoch 190: Loss = 0.0050
# XOM - Epoch 200: Loss = 0.0060
# XOM - Epoch 210: Loss = 0.0055
# XOM - Epoch 220: Loss = 0.0053
# XOM - Epoch 230: Loss = 0.0046
# XOM - Epoch 240: Loss = 0.0053
# XOM Baseline - Epoch 0: Loss = 0.1131
# XOM Baseline - Epoch 10: Loss = 0.0319
# XOM Baseline - Epoch 20: Loss = 0.0036
# XOM Baseline - Epoch 30: Loss = 0.0042
# XOM Baseline - Epoch 40: Loss = 0.0035
# XOM Baseline - Epoch 50: Loss = 0.0045
# XOM Baseline - Epoch 60: Loss = 0.0045
# XOM Baseline - Epoch 70: Loss = 0.0040
# XOM Baseline - Epoch 80: Loss = 0.0041
# XOM Baseline - Epoch 90: Loss = 0.0034
# XOM Baseline - Epoch 100: Loss = 0.0037
# XOM Baseline - Epoch 110: Loss = 0.0036
# XOM Baseline - Epoch 120: Loss = 0.0033
# XOM Baseline - Epoch 130: Loss = 0.0034
# XOM Baseline - Epoch 140: Loss = 0.0029
# XOM Baseline - Epoch 150: Loss = 0.0029
# XOM Baseline - Epoch 160: Loss = 0.0033
# XOM Baseline - Epoch 170: Loss = 0.0035
# XOM Baseline - Epoch 180: Loss = 0.0037
# XOM Baseline - Epoch 190: Loss = 0.0038
# XOM Baseline - Epoch 200: Loss = 0.0028
# XOM Baseline - Epoch 210: Loss = 0.0029
# XOM Baseline - Epoch 220: Loss = 0.0032
# XOM Baseline - Epoch 230: Loss = 0.0038
# XOM Baseline - Epoch 240: Loss = 0.0031
#
# Processing CVX
# Matched data points: 5
# Error processing CVX: Insufficient data points. Need at least 6 points, got 5
#
# Processing NFLX
# Matched data points: 157
# NFLX - Epoch 0: Loss = 0.3696
# NFLX - Epoch 10: Loss = 0.0592
# NFLX - Epoch 20: Loss = 0.0424
# NFLX - Epoch 30: Loss = 0.0130
# NFLX - Epoch 40: Loss = 0.0109
# NFLX - Epoch 50: Loss = 0.0097
# NFLX - Epoch 60: Loss = 0.0105
# NFLX - Epoch 70: Loss = 0.0074
# NFLX - Epoch 80: Loss = 0.0078
# NFLX - Epoch 90: Loss = 0.0079
# NFLX - Epoch 100: Loss = 0.0071
# NFLX - Epoch 110: Loss = 0.0077
# NFLX - Epoch 120: Loss = 0.0076
# NFLX - Epoch 130: Loss = 0.0066
# NFLX - Epoch 140: Loss = 0.0073
# NFLX - Epoch 150: Loss = 0.0067
# NFLX - Epoch 160: Loss = 0.0065
# NFLX - Epoch 170: Loss = 0.0071
# NFLX - Epoch 180: Loss = 0.0067
# NFLX - Epoch 190: Loss = 0.0067
# NFLX - Epoch 200: Loss = 0.0065
# NFLX - Epoch 210: Loss = 0.0065
# NFLX - Epoch 220: Loss = 0.0072
# NFLX - Epoch 230: Loss = 0.0064
# NFLX - Epoch 240: Loss = 0.0061
# NFLX Baseline - Epoch 0: Loss = 0.5219
# NFLX Baseline - Epoch 10: Loss = 0.0335
# NFLX Baseline - Epoch 20: Loss = 0.0093
# NFLX Baseline - Epoch 30: Loss = 0.0069
# NFLX Baseline - Epoch 40: Loss = 0.0062
# NFLX Baseline - Epoch 50: Loss = 0.0069
# NFLX Baseline - Epoch 60: Loss = 0.0057
# NFLX Baseline - Epoch 70: Loss = 0.0071
# NFLX Baseline - Epoch 80: Loss = 0.0065
# NFLX Baseline - Epoch 90: Loss = 0.0072
# NFLX Baseline - Epoch 100: Loss = 0.0053
# NFLX Baseline - Epoch 110: Loss = 0.0067
# NFLX Baseline - Epoch 120: Loss = 0.0056
# NFLX Baseline - Epoch 130: Loss = 0.0041
# NFLX Baseline - Epoch 140: Loss = 0.0045
# NFLX Baseline - Epoch 150: Loss = 0.0057
# NFLX Baseline - Epoch 160: Loss = 0.0044
# NFLX Baseline - Epoch 170: Loss = 0.0046
# NFLX Baseline - Epoch 180: Loss = 0.0042
# NFLX Baseline - Epoch 190: Loss = 0.0045
# NFLX Baseline - Epoch 200: Loss = 0.0052
# NFLX Baseline - Epoch 210: Loss = 0.0040
# NFLX Baseline - Epoch 220: Loss = 0.0042
# NFLX Baseline - Epoch 230: Loss = 0.0039
# NFLX Baseline - Epoch 240: Loss = 0.0046
#
# Processing TSLA
# Matched data points: 250
# TSLA - Epoch 0: Loss = 0.1393
# TSLA - Epoch 10: Loss = 0.0400
# TSLA - Epoch 20: Loss = 0.0038
# TSLA - Epoch 30: Loss = 0.0028
# TSLA - Epoch 40: Loss = 0.0067
# TSLA - Epoch 50: Loss = 0.0021
# TSLA - Epoch 60: Loss = 0.0025
# TSLA - Epoch 70: Loss = 0.0055
# TSLA - Epoch 80: Loss = 0.0028
# TSLA - Epoch 90: Loss = 0.0023
# TSLA - Epoch 100: Loss = 0.0030
# TSLA - Epoch 110: Loss = 0.0028
# TSLA - Epoch 120: Loss = 0.0025
# TSLA - Epoch 130: Loss = 0.0026
# TSLA - Epoch 140: Loss = 0.0022
# TSLA - Epoch 150: Loss = 0.0023
# TSLA - Epoch 160: Loss = 0.0017
# TSLA - Epoch 170: Loss = 0.0021
# TSLA - Epoch 180: Loss = 0.0022
# TSLA - Epoch 190: Loss = 0.0023
# TSLA - Epoch 200: Loss = 0.0028
# TSLA - Epoch 210: Loss = 0.0018
# TSLA - Epoch 220: Loss = 0.0020
# TSLA - Epoch 230: Loss = 0.0016
# TSLA - Epoch 240: Loss = 0.0016
# TSLA Baseline - Epoch 0: Loss = 0.1122
# TSLA Baseline - Epoch 10: Loss = 0.0551
# TSLA Baseline - Epoch 20: Loss = 0.0034
# TSLA Baseline - Epoch 30: Loss = 0.0025
# TSLA Baseline - Epoch 40: Loss = 0.0026
# TSLA Baseline - Epoch 50: Loss = 0.0026
# TSLA Baseline - Epoch 60: Loss = 0.0029
# TSLA Baseline - Epoch 70: Loss = 0.0023
# TSLA Baseline - Epoch 80: Loss = 0.0025
# TSLA Baseline - Epoch 90: Loss = 0.0023
# TSLA Baseline - Epoch 100: Loss = 0.0025
# TSLA Baseline - Epoch 110: Loss = 0.0021
# TSLA Baseline - Epoch 120: Loss = 0.0020
# TSLA Baseline - Epoch 130: Loss = 0.0020
# TSLA Baseline - Epoch 140: Loss = 0.0020
# TSLA Baseline - Epoch 150: Loss = 0.0021
# TSLA Baseline - Epoch 160: Loss = 0.0021
# TSLA Baseline - Epoch 170: Loss = 0.0016
# TSLA Baseline - Epoch 180: Loss = 0.0018
# TSLA Baseline - Epoch 190: Loss = 0.0016
# TSLA Baseline - Epoch 200: Loss = 0.0023
# TSLA Baseline - Epoch 210: Loss = 0.0016
# TSLA Baseline - Epoch 220: Loss = 0.0017
# TSLA Baseline - Epoch 230: Loss = 0.0015
# TSLA Baseline - Epoch 240: Loss = 0.0019
#
# Processing NKE
# Matched data points: 41
# NKE - Epoch 0: Loss = 0.4116
# NKE - Epoch 10: Loss = 0.2794
# NKE - Epoch 20: Loss = 0.1625
# NKE - Epoch 30: Loss = 0.0768
# NKE - Epoch 40: Loss = 0.0760
# NKE - Epoch 50: Loss = 0.0645
# NKE - Epoch 60: Loss = 0.0642
# NKE - Epoch 70: Loss = 0.0590
# NKE - Epoch 80: Loss = 0.0540
# NKE - Epoch 90: Loss = 0.0476
# NKE - Epoch 100: Loss = 0.0421
# NKE - Epoch 110: Loss = 0.0372
# NKE - Epoch 120: Loss = 0.0273
# NKE - Epoch 130: Loss = 0.0213
# NKE - Epoch 140: Loss = 0.0195
# NKE - Epoch 150: Loss = 0.0168
# NKE - Epoch 160: Loss = 0.0204
# NKE - Epoch 170: Loss = 0.0184
# NKE - Epoch 180: Loss = 0.0171
# NKE - Epoch 190: Loss = 0.0172
# NKE - Epoch 200: Loss = 0.0179
# NKE - Epoch 210: Loss = 0.0173
# NKE - Epoch 220: Loss = 0.0201
# NKE - Epoch 230: Loss = 0.0174
# NKE - Epoch 240: Loss = 0.0174
# NKE Baseline - Epoch 0: Loss = 0.4346
# NKE Baseline - Epoch 10: Loss = 0.0423
# NKE Baseline - Epoch 20: Loss = 0.0138
# NKE Baseline - Epoch 30: Loss = 0.0037
# NKE Baseline - Epoch 40: Loss = 0.0040
# NKE Baseline - Epoch 50: Loss = 0.0039
# NKE Baseline - Epoch 60: Loss = 0.0033
# NKE Baseline - Epoch 70: Loss = 0.0029
# NKE Baseline - Epoch 80: Loss = 0.0028
# NKE Baseline - Epoch 90: Loss = 0.0028
# NKE Baseline - Epoch 100: Loss = 0.0026
# NKE Baseline - Epoch 110: Loss = 0.0027
# NKE Baseline - Epoch 120: Loss = 0.0031
# NKE Baseline - Epoch 130: Loss = 0.0031
# NKE Baseline - Epoch 140: Loss = 0.0023
# NKE Baseline - Epoch 150: Loss = 0.0031
# NKE Baseline - Epoch 160: Loss = 0.0023
# NKE Baseline - Epoch 170: Loss = 0.0030
# NKE Baseline - Epoch 180: Loss = 0.0028
# NKE Baseline - Epoch 190: Loss = 0.0028
# NKE Baseline - Epoch 200: Loss = 0.0022
# NKE Baseline - Epoch 210: Loss = 0.0031
# NKE Baseline - Epoch 220: Loss = 0.0022
# NKE Baseline - Epoch 230: Loss = 0.0020
# NKE Baseline - Epoch 240: Loss = 0.0034
#
# Processing PFE
# Matched data points: 99
# PFE - Epoch 0: Loss = 0.1642
# PFE - Epoch 10: Loss = 0.0322
# PFE - Epoch 20: Loss = 0.0216
# PFE - Epoch 30: Loss = 0.0241
# PFE - Epoch 40: Loss = 0.0142
# PFE - Epoch 50: Loss = 0.0126
# PFE - Epoch 60: Loss = 0.0125
# PFE - Epoch 70: Loss = 0.0129
# PFE - Epoch 80: Loss = 0.0167
# PFE - Epoch 90: Loss = 0.0091
# PFE - Epoch 100: Loss = 0.0116
# PFE - Epoch 110: Loss = 0.0110
# PFE - Epoch 120: Loss = 0.0099
# PFE - Epoch 130: Loss = 0.0101
# PFE - Epoch 140: Loss = 0.0086
# PFE - Epoch 150: Loss = 0.0093
# PFE - Epoch 160: Loss = 0.0087
# PFE - Epoch 170: Loss = 0.0097
# PFE - Epoch 180: Loss = 0.0106
# PFE - Epoch 190: Loss = 0.0070
# PFE - Epoch 200: Loss = 0.0094
# PFE - Epoch 210: Loss = 0.0090
# PFE - Epoch 220: Loss = 0.0049
# PFE - Epoch 230: Loss = 0.0055
# PFE - Epoch 240: Loss = 0.0048
# PFE Baseline - Epoch 0: Loss = 0.3165
# PFE Baseline - Epoch 10: Loss = 0.0206
# PFE Baseline - Epoch 20: Loss = 0.0157
# PFE Baseline - Epoch 30: Loss = 0.0053
# PFE Baseline - Epoch 40: Loss = 0.0054
# PFE Baseline - Epoch 50: Loss = 0.0052
# PFE Baseline - Epoch 60: Loss = 0.0045
# PFE Baseline - Epoch 70: Loss = 0.0044
# PFE Baseline - Epoch 80: Loss = 0.0061
# PFE Baseline - Epoch 90: Loss = 0.0044
# PFE Baseline - Epoch 100: Loss = 0.0046
# PFE Baseline - Epoch 110: Loss = 0.0042
# PFE Baseline - Epoch 120: Loss = 0.0047
# PFE Baseline - Epoch 130: Loss = 0.0048
# PFE Baseline - Epoch 140: Loss = 0.0038
# PFE Baseline - Epoch 150: Loss = 0.0038
# PFE Baseline - Epoch 160: Loss = 0.0038
# PFE Baseline - Epoch 170: Loss = 0.0055
# PFE Baseline - Epoch 180: Loss = 0.0036
# PFE Baseline - Epoch 190: Loss = 0.0042
# PFE Baseline - Epoch 200: Loss = 0.0044
# PFE Baseline - Epoch 210: Loss = 0.0047
# PFE Baseline - Epoch 220: Loss = 0.0037
# PFE Baseline - Epoch 230: Loss = 0.0033
# PFE Baseline - Epoch 240: Loss = 0.0029
#
# Processing UNH
# Matched data points: 16
# UNH - Epoch 0: Loss = 0.2309
# UNH - Epoch 10: Loss = 0.1667
# UNH - Epoch 20: Loss = 0.1135
# UNH - Epoch 30: Loss = 0.0736
# UNH - Epoch 40: Loss = 0.0562
# UNH - Epoch 50: Loss = 0.0583
# UNH - Epoch 60: Loss = 0.0567
# UNH - Epoch 70: Loss = 0.0550
# UNH - Epoch 80: Loss = 0.0508
# UNH - Epoch 90: Loss = 0.0565
# UNH - Epoch 100: Loss = 0.0543
# UNH - Epoch 110: Loss = 0.0522
# UNH - Epoch 120: Loss = 0.0515
# UNH - Epoch 130: Loss = 0.0507
# UNH - Epoch 140: Loss = 0.0535
# UNH - Epoch 150: Loss = 0.0539
# UNH - Epoch 160: Loss = 0.0528
# UNH - Epoch 170: Loss = 0.0551
# UNH - Epoch 180: Loss = 0.0495
# UNH - Epoch 190: Loss = 0.0535
# UNH - Epoch 200: Loss = 0.0507
# UNH - Epoch 210: Loss = 0.0516
# UNH - Epoch 220: Loss = 0.0524
# UNH - Epoch 230: Loss = 0.0518
# UNH - Epoch 240: Loss = 0.0503
# UNH Baseline - Epoch 0: Loss = 0.6203
# UNH Baseline - Epoch 10: Loss = 0.0307
# UNH Baseline - Epoch 20: Loss = 0.0166
# UNH Baseline - Epoch 30: Loss = 0.0086
# UNH Baseline - Epoch 40: Loss = 0.0076
# UNH Baseline - Epoch 50: Loss = 0.0064
# UNH Baseline - Epoch 60: Loss = 0.0067
# UNH Baseline - Epoch 70: Loss = 0.0061
# UNH Baseline - Epoch 80: Loss = 0.0060
# UNH Baseline - Epoch 90: Loss = 0.0062
# UNH Baseline - Epoch 100: Loss = 0.0069
# UNH Baseline - Epoch 110: Loss = 0.0060
# UNH Baseline - Epoch 120: Loss = 0.0061
# UNH Baseline - Epoch 130: Loss = 0.0056
# UNH Baseline - Epoch 140: Loss = 0.0053
# UNH Baseline - Epoch 150: Loss = 0.0051
# UNH Baseline - Epoch 160: Loss = 0.0052
# UNH Baseline - Epoch 170: Loss = 0.0064
# UNH Baseline - Epoch 180: Loss = 0.0052
# UNH Baseline - Epoch 190: Loss = 0.0048
# UNH Baseline - Epoch 200: Loss = 0.0044
# UNH Baseline - Epoch 210: Loss = 0.0042
# UNH Baseline - Epoch 220: Loss = 0.0044
# UNH Baseline - Epoch 230: Loss = 0.0040
# UNH Baseline - Epoch 240: Loss = 0.0048
#
# Processing ABNB
# Matched data points: 14
# ABNB - Epoch 0: Loss = 0.9185
# ABNB - Epoch 10: Loss = 0.7120
# ABNB - Epoch 20: Loss = 0.5018
# ABNB - Epoch 30: Loss = 0.2525
# ABNB - Epoch 40: Loss = 0.0317
# ABNB - Epoch 50: Loss = 0.0693
# ABNB - Epoch 60: Loss = 0.0200
# ABNB - Epoch 70: Loss = 0.0232
# ABNB - Epoch 80: Loss = 0.0286
# ABNB - Epoch 90: Loss = 0.0299
# ABNB - Epoch 100: Loss = 0.0163
# ABNB - Epoch 110: Loss = 0.0278
# ABNB - Epoch 120: Loss = 0.0164
# ABNB - Epoch 130: Loss = 0.0150
# ABNB - Epoch 140: Loss = 0.0224
# ABNB - Epoch 150: Loss = 0.0167
# ABNB - Epoch 160: Loss = 0.0161
# ABNB - Epoch 170: Loss = 0.0154
# ABNB - Epoch 180: Loss = 0.0180
# ABNB - Epoch 190: Loss = 0.0118
# ABNB - Epoch 200: Loss = 0.0142
# ABNB - Epoch 210: Loss = 0.0148
# ABNB - Epoch 220: Loss = 0.0135
# ABNB - Epoch 230: Loss = 0.0104
# ABNB - Epoch 240: Loss = 0.0116
# ABNB Baseline - Epoch 0: Loss = 0.7023
# ABNB Baseline - Epoch 10: Loss = 0.5344
# ABNB Baseline - Epoch 20: Loss = 0.3383
# ABNB Baseline - Epoch 30: Loss = 0.1390
# ABNB Baseline - Epoch 40: Loss = 0.0492
# ABNB Baseline - Epoch 50: Loss = 0.0453
# ABNB Baseline - Epoch 60: Loss = 0.0375
# ABNB Baseline - Epoch 70: Loss = 0.0369
# ABNB Baseline - Epoch 80: Loss = 0.0348
# ABNB Baseline - Epoch 90: Loss = 0.0333
# ABNB Baseline - Epoch 100: Loss = 0.0253
# ABNB Baseline - Epoch 110: Loss = 0.0285
# ABNB Baseline - Epoch 120: Loss = 0.0271
# ABNB Baseline - Epoch 130: Loss = 0.0294
# ABNB Baseline - Epoch 140: Loss = 0.0302
# ABNB Baseline - Epoch 150: Loss = 0.0300
# ABNB Baseline - Epoch 160: Loss = 0.0383
# ABNB Baseline - Epoch 170: Loss = 0.0290
# ABNB Baseline - Epoch 180: Loss = 0.0317
# ABNB Baseline - Epoch 190: Loss = 0.0310
# ABNB Baseline - Epoch 200: Loss = 0.0296
# ABNB Baseline - Epoch 210: Loss = 0.0219
# ABNB Baseline - Epoch 220: Loss = 0.0220
# ABNB Baseline - Epoch 230: Loss = 0.0224
# ABNB Baseline - Epoch 240: Loss = 0.0207
#
# Processing KO
# Matched data points: 28
# KO - Epoch 0: Loss = 0.1544
# KO - Epoch 10: Loss = 0.0854
# KO - Epoch 20: Loss = 0.0321
# KO - Epoch 30: Loss = 0.0323
# KO - Epoch 40: Loss = 0.0269
# KO - Epoch 50: Loss = 0.0276
# KO - Epoch 60: Loss = 0.0285
# KO - Epoch 70: Loss = 0.0247
# KO - Epoch 80: Loss = 0.0249
# KO - Epoch 90: Loss = 0.0254
# KO - Epoch 100: Loss = 0.0225
# KO - Epoch 110: Loss = 0.0227
# KO - Epoch 120: Loss = 0.0228
# KO - Epoch 130: Loss = 0.0213
# KO - Epoch 140: Loss = 0.0207
# KO - Epoch 150: Loss = 0.0181
# KO - Epoch 160: Loss = 0.0166
# KO - Epoch 170: Loss = 0.0163
# KO - Epoch 180: Loss = 0.0124
# KO - Epoch 190: Loss = 0.0137
# KO - Epoch 200: Loss = 0.0114
# KO - Epoch 210: Loss = 0.0128
# KO - Epoch 220: Loss = 0.0119
# KO - Epoch 230: Loss = 0.0096
# KO - Epoch 240: Loss = 0.0090
# KO Baseline - Epoch 0: Loss = 0.2898
# KO Baseline - Epoch 10: Loss = 0.0366
# KO Baseline - Epoch 20: Loss = 0.0143
# KO Baseline - Epoch 30: Loss = 0.0068
# KO Baseline - Epoch 40: Loss = 0.0068
# KO Baseline - Epoch 50: Loss = 0.0078
# KO Baseline - Epoch 60: Loss = 0.0089
# KO Baseline - Epoch 70: Loss = 0.0064
# KO Baseline - Epoch 80: Loss = 0.0062
# KO Baseline - Epoch 90: Loss = 0.0058
# KO Baseline - Epoch 100: Loss = 0.0058
# KO Baseline - Epoch 110: Loss = 0.0058
# KO Baseline - Epoch 120: Loss = 0.0057
# KO Baseline - Epoch 130: Loss = 0.0054
# KO Baseline - Epoch 140: Loss = 0.0053
# KO Baseline - Epoch 150: Loss = 0.0050
# KO Baseline - Epoch 160: Loss = 0.0049
# KO Baseline - Epoch 170: Loss = 0.0056
# KO Baseline - Epoch 180: Loss = 0.0050
# KO Baseline - Epoch 190: Loss = 0.0041
# KO Baseline - Epoch 200: Loss = 0.0039
# KO Baseline - Epoch 210: Loss = 0.0039
# KO Baseline - Epoch 220: Loss = 0.0037
# KO Baseline - Epoch 230: Loss = 0.0044
# KO Baseline - Epoch 240: Loss = 0.0036
#
# Processing JNJ
# Matched data points: 49
# JNJ - Epoch 0: Loss = 0.2813
# JNJ - Epoch 10: Loss = 0.0747
# JNJ - Epoch 20: Loss = 0.0361
# JNJ - Epoch 30: Loss = 0.1481
# JNJ - Epoch 40: Loss = 0.0272
# JNJ - Epoch 50: Loss = 0.0337
# JNJ - Epoch 60: Loss = 0.0318
# JNJ - Epoch 70: Loss = 0.0758
# JNJ - Epoch 80: Loss = 0.0644
# JNJ - Epoch 90: Loss = 0.0311
# JNJ - Epoch 100: Loss = 0.0459
# JNJ - Epoch 110: Loss = 0.0293
# JNJ - Epoch 120: Loss = 0.0229
# JNJ - Epoch 130: Loss = 0.0219
# JNJ - Epoch 140: Loss = 0.0404
# JNJ - Epoch 150: Loss = 0.0677
# JNJ - Epoch 160: Loss = 0.0285
# JNJ - Epoch 170: Loss = 0.0204
# JNJ - Epoch 180: Loss = 0.0349
# JNJ - Epoch 190: Loss = 0.0395
# JNJ - Epoch 200: Loss = 0.1168
# JNJ - Epoch 210: Loss = 0.0285
# JNJ - Epoch 220: Loss = 0.0236
# JNJ - Epoch 230: Loss = 0.0410
# JNJ - Epoch 240: Loss = 0.0189
# JNJ Baseline - Epoch 0: Loss = 0.5237
# JNJ Baseline - Epoch 10: Loss = 0.0158
# JNJ Baseline - Epoch 20: Loss = 0.0136
# JNJ Baseline - Epoch 30: Loss = 0.0102
# JNJ Baseline - Epoch 40: Loss = 0.0085
# JNJ Baseline - Epoch 50: Loss = 0.0071
# JNJ Baseline - Epoch 60: Loss = 0.0065
# JNJ Baseline - Epoch 70: Loss = 0.0068
# JNJ Baseline - Epoch 80: Loss = 0.0067
# JNJ Baseline - Epoch 90: Loss = 0.0064
# JNJ Baseline - Epoch 100: Loss = 0.0069
# JNJ Baseline - Epoch 110: Loss = 0.0067
# JNJ Baseline - Epoch 120: Loss = 0.0061
# JNJ Baseline - Epoch 130: Loss = 0.0067
# JNJ Baseline - Epoch 140: Loss = 0.0052
# JNJ Baseline - Epoch 150: Loss = 0.0050
# JNJ Baseline - Epoch 160: Loss = 0.0057
# JNJ Baseline - Epoch 170: Loss = 0.0045
# JNJ Baseline - Epoch 180: Loss = 0.0050
# JNJ Baseline - Epoch 190: Loss = 0.0050
# JNJ Baseline - Epoch 200: Loss = 0.0048
# JNJ Baseline - Epoch 210: Loss = 0.0069
# JNJ Baseline - Epoch 220: Loss = 0.0048
# JNJ Baseline - Epoch 230: Loss = 0.0059
# JNJ Baseline - Epoch 240: Loss = 0.0037
#
# Processing SBUX
# Matched data points: 65
# SBUX - Epoch 0: Loss = 0.1899
# SBUX - Epoch 10: Loss = 0.0438
# SBUX - Epoch 20: Loss = 0.0468
# SBUX - Epoch 30: Loss = 0.0333
# SBUX - Epoch 40: Loss = 0.0314
# SBUX - Epoch 50: Loss = 0.0248
# SBUX - Epoch 60: Loss = 0.0194
# SBUX - Epoch 70: Loss = 0.0165
# SBUX - Epoch 80: Loss = 0.0173
# SBUX - Epoch 90: Loss = 0.0106
# SBUX - Epoch 100: Loss = 0.0125
# SBUX - Epoch 110: Loss = 0.0160
# SBUX - Epoch 120: Loss = 0.0134
# SBUX - Epoch 130: Loss = 0.0113
# SBUX - Epoch 140: Loss = 0.0147
# SBUX - Epoch 150: Loss = 0.0149
# SBUX - Epoch 160: Loss = 0.0098
# SBUX - Epoch 170: Loss = 0.0125
# SBUX - Epoch 180: Loss = 0.0100
# SBUX - Epoch 190: Loss = 0.0114
# SBUX - Epoch 200: Loss = 0.0109
# SBUX - Epoch 210: Loss = 0.0112
# SBUX - Epoch 220: Loss = 0.0126
# SBUX - Epoch 230: Loss = 0.0096
# SBUX - Epoch 240: Loss = 0.0100
# SBUX Baseline - Epoch 0: Loss = 0.1953
# SBUX Baseline - Epoch 10: Loss = 0.0326
# SBUX Baseline - Epoch 20: Loss = 0.0124
# SBUX Baseline - Epoch 30: Loss = 0.0052
# SBUX Baseline - Epoch 40: Loss = 0.0044
# SBUX Baseline - Epoch 50: Loss = 0.0040
# SBUX Baseline - Epoch 60: Loss = 0.0043
# SBUX Baseline - Epoch 70: Loss = 0.0040
# SBUX Baseline - Epoch 80: Loss = 0.0045
# SBUX Baseline - Epoch 90: Loss = 0.0037
# SBUX Baseline - Epoch 100: Loss = 0.0040
# SBUX Baseline - Epoch 110: Loss = 0.0038
# SBUX Baseline - Epoch 120: Loss = 0.0031
# SBUX Baseline - Epoch 130: Loss = 0.0038
# SBUX Baseline - Epoch 140: Loss = 0.0037
# SBUX Baseline - Epoch 150: Loss = 0.0036
# SBUX Baseline - Epoch 160: Loss = 0.0034
# SBUX Baseline - Epoch 170: Loss = 0.0038
# SBUX Baseline - Epoch 180: Loss = 0.0028
# SBUX Baseline - Epoch 190: Loss = 0.0034
# SBUX Baseline - Epoch 200: Loss = 0.0028
# SBUX Baseline - Epoch 210: Loss = 0.0031
# SBUX Baseline - Epoch 220: Loss = 0.0032
# SBUX Baseline - Epoch 230: Loss = 0.0030
# SBUX Baseline - Epoch 240: Loss = 0.0027
#
# Processing BAC
# Matched data points: 90
# BAC - Epoch 0: Loss = 0.0350
# BAC - Epoch 10: Loss = 0.0250
# BAC - Epoch 20: Loss = 0.0259
# BAC - Epoch 30: Loss = 0.0210
# BAC - Epoch 40: Loss = 0.0162
# BAC - Epoch 50: Loss = 0.0202
# BAC - Epoch 60: Loss = 0.0148
# BAC - Epoch 70: Loss = 0.0141
# BAC - Epoch 80: Loss = 0.0140
# BAC - Epoch 90: Loss = 0.0112
# BAC - Epoch 100: Loss = 0.0240
# BAC - Epoch 110: Loss = 0.0192
# BAC - Epoch 120: Loss = 0.0218
# BAC - Epoch 130: Loss = 0.0095
# BAC - Epoch 140: Loss = 0.0133
# BAC - Epoch 150: Loss = 0.0107
# BAC - Epoch 160: Loss = 0.0110
# BAC - Epoch 170: Loss = 0.0108
# BAC - Epoch 180: Loss = 0.0104
# BAC - Epoch 190: Loss = 0.0090
# BAC - Epoch 200: Loss = 0.0092
# BAC - Epoch 210: Loss = 0.0114
# BAC - Epoch 220: Loss = 0.0121
# BAC - Epoch 230: Loss = 0.0121
# BAC - Epoch 240: Loss = 0.0112
# BAC Baseline - Epoch 0: Loss = 0.2321
# BAC Baseline - Epoch 10: Loss = 0.0310
# BAC Baseline - Epoch 20: Loss = 0.0068
# BAC Baseline - Epoch 30: Loss = 0.0063
# BAC Baseline - Epoch 40: Loss = 0.0071
# BAC Baseline - Epoch 50: Loss = 0.0062
# BAC Baseline - Epoch 60: Loss = 0.0057
# BAC Baseline - Epoch 70: Loss = 0.0062
# BAC Baseline - Epoch 80: Loss = 0.0086
# BAC Baseline - Epoch 90: Loss = 0.0067
# BAC Baseline - Epoch 100: Loss = 0.0070
# BAC Baseline - Epoch 110: Loss = 0.0057
# BAC Baseline - Epoch 120: Loss = 0.0060
# BAC Baseline - Epoch 130: Loss = 0.0052
# BAC Baseline - Epoch 140: Loss = 0.0049
# BAC Baseline - Epoch 150: Loss = 0.0047
# BAC Baseline - Epoch 160: Loss = 0.0047
# BAC Baseline - Epoch 170: Loss = 0.0048
# BAC Baseline - Epoch 180: Loss = 0.0043
# BAC Baseline - Epoch 190: Loss = 0.0048
# BAC Baseline - Epoch 200: Loss = 0.0043
# BAC Baseline - Epoch 210: Loss = 0.0044
# BAC Baseline - Epoch 220: Loss = 0.0041
# BAC Baseline - Epoch 230: Loss = 0.0045
# BAC Baseline - Epoch 240: Loss = 0.0036
#
# Processing NVDA
# Matched data points: 140
# NVDA - Epoch 0: Loss = 0.2860
# NVDA - Epoch 10: Loss = 0.0747
# NVDA - Epoch 20: Loss = 0.0248
# NVDA - Epoch 30: Loss = 0.0059
# NVDA - Epoch 40: Loss = 0.0055
# NVDA - Epoch 50: Loss = 0.0043
# NVDA - Epoch 60: Loss = 0.0044
# NVDA - Epoch 70: Loss = 0.0045
# NVDA - Epoch 80: Loss = 0.0049
# NVDA - Epoch 90: Loss = 0.0031
# NVDA - Epoch 100: Loss = 0.0040
# NVDA - Epoch 110: Loss = 0.0035
# NVDA - Epoch 120: Loss = 0.0035
# NVDA - Epoch 130: Loss = 0.0034
# NVDA - Epoch 140: Loss = 0.0033
# NVDA - Epoch 150: Loss = 0.0031
# NVDA - Epoch 160: Loss = 0.0034
# NVDA - Epoch 170: Loss = 0.0031
# NVDA - Epoch 180: Loss = 0.0032
# NVDA - Epoch 190: Loss = 0.0028
# NVDA - Epoch 200: Loss = 0.0033
# NVDA - Epoch 210: Loss = 0.0027
# NVDA - Epoch 220: Loss = 0.0028
# NVDA - Epoch 230: Loss = 0.0032
# NVDA - Epoch 240: Loss = 0.0029
# NVDA Baseline - Epoch 0: Loss = 0.1754
# NVDA Baseline - Epoch 10: Loss = 0.0390
# NVDA Baseline - Epoch 20: Loss = 0.0054
# NVDA Baseline - Epoch 30: Loss = 0.0036
# NVDA Baseline - Epoch 40: Loss = 0.0035
# NVDA Baseline - Epoch 50: Loss = 0.0030
# NVDA Baseline - Epoch 60: Loss = 0.0032
# NVDA Baseline - Epoch 70: Loss = 0.0025
# NVDA Baseline - Epoch 80: Loss = 0.0030
# NVDA Baseline - Epoch 90: Loss = 0.0025
# NVDA Baseline - Epoch 100: Loss = 0.0035
# NVDA Baseline - Epoch 110: Loss = 0.0030
# NVDA Baseline - Epoch 120: Loss = 0.0027
# NVDA Baseline - Epoch 130: Loss = 0.0023
# NVDA Baseline - Epoch 140: Loss = 0.0025
# NVDA Baseline - Epoch 150: Loss = 0.0028
# NVDA Baseline - Epoch 160: Loss = 0.0023
# NVDA Baseline - Epoch 170: Loss = 0.0031
# NVDA Baseline - Epoch 180: Loss = 0.0026
# NVDA Baseline - Epoch 190: Loss = 0.0021
# NVDA Baseline - Epoch 200: Loss = 0.0021
# NVDA Baseline - Epoch 210: Loss = 0.0021
# NVDA Baseline - Epoch 220: Loss = 0.0022
# NVDA Baseline - Epoch 230: Loss = 0.0023
# NVDA Baseline - Epoch 240: Loss = 0.0023
#
# Average MSE Improvement: -314.74%
#
# MSE Comparison by Ticker:
# BA:
#   Sentiment LSTM MSE: 148.863998
#   Baseline LSTM MSE: 220.139908
#   Improvement: 32.38%
# CCL:
#   Sentiment LSTM MSE: 5.661118
#   Baseline LSTM MSE: 3.459497
#   Improvement: -63.64%
# PG:
#   Sentiment LSTM MSE: 24.499323
#   Baseline LSTM MSE: 12.959640
#   Improvement: -89.04%
# TSM:
#   Sentiment LSTM MSE: 40.016869
#   Baseline LSTM MSE: 11.044607
#   Improvement: -262.32%
# HD:
#   Sentiment LSTM MSE: 50.961784
#   Baseline LSTM MSE: 25.171486
#   Improvement: -102.46%
# PYPL:
#   Sentiment LSTM MSE: 206.622849
#   Baseline LSTM MSE: 47.573925
#   Improvement: -334.32%
# WMT:
#   Sentiment LSTM MSE: 1.415816
#   Baseline LSTM MSE: 0.709884
#   Improvement: -99.44%
# V:
#   Sentiment LSTM MSE: 55.022842
#   Baseline LSTM MSE: 23.105469
#   Improvement: -138.14%
# BABA:
#   Sentiment LSTM MSE: 55.236881
#   Baseline LSTM MSE: 48.469849
#   Improvement: -13.96%
# MSFT:
#   Sentiment LSTM MSE: 43.052319
#   Baseline LSTM MSE: 29.537527
#   Improvement: -45.75%
# BKNG:
#   Sentiment LSTM MSE: 31130.173828
#   Baseline LSTM MSE: 5773.537109
#   Improvement: -439.19%
# DIS:
#   Sentiment LSTM MSE: 27.649757
#   Baseline LSTM MSE: 15.144563
#   Improvement: -82.57%
# AMZN:
#   Sentiment LSTM MSE: 15.675093
#   Baseline LSTM MSE: 19.495869
#   Improvement: 19.60%
# AAPL:
#   Sentiment LSTM MSE: 19.554096
#   Baseline LSTM MSE: 12.409597
#   Improvement: -57.57%
# JPM:
#   Sentiment LSTM MSE: 14.213901
#   Baseline LSTM MSE: 14.543458
#   Improvement: 2.27%
# GOOGL:
#   Sentiment LSTM MSE: 39.593628
#   Baseline LSTM MSE: 3.282916
#   Improvement: -1106.05%
# MA:
#   Sentiment LSTM MSE: 1408.872314
#   Baseline LSTM MSE: 58.410820
#   Improvement: -2312.01%
# GOOG:
#   Sentiment LSTM MSE: 61.654022
#   Baseline LSTM MSE: 7.153650
#   Improvement: -761.85%
# MCD:
#   Sentiment LSTM MSE: 145.736053
#   Baseline LSTM MSE: 17.124262
#   Improvement: -751.05%
# UPS:
#   Sentiment LSTM MSE: 75.412796
#   Baseline LSTM MSE: 14.544979
#   Improvement: -418.48%
# LOW:
#   Sentiment LSTM MSE: 81.775803
#   Baseline LSTM MSE: 20.498291
#   Improvement: -298.94%
# XOM:
#   Sentiment LSTM MSE: 6.820844
#   Baseline LSTM MSE: 1.887471
#   Improvement: -261.37%
# NFLX:
#   Sentiment LSTM MSE: 367.152435
#   Baseline LSTM MSE: 185.715073
#   Improvement: -97.70%
# TSLA:
#   Sentiment LSTM MSE: 71.267715
#   Baseline LSTM MSE: 52.823975
#   Improvement: -34.92%
# NKE:
#   Sentiment LSTM MSE: 64.721054
#   Baseline LSTM MSE: 11.458539
#   Improvement: -464.83%
# PFE:
#   Sentiment LSTM MSE: 0.738126
#   Baseline LSTM MSE: 0.553251
#   Improvement: -33.42%
# UNH:
#   Sentiment LSTM MSE: 215.150253
#   Baseline LSTM MSE: 89.922897
#   Improvement: -139.26%
# ABNB:
#   Sentiment LSTM MSE: 74.620628
#   Baseline LSTM MSE: 5.977204
#   Improvement: -1148.42%
# KO:
#   Sentiment LSTM MSE: 2.770375
#   Baseline LSTM MSE: 0.766272
#   Improvement: -261.54%
# JNJ:
#   Sentiment LSTM MSE: 26.313772
#   Baseline LSTM MSE: 7.620961
#   Improvement: -245.28%
# SBUX:
#   Sentiment LSTM MSE: 13.300744
#   Baseline LSTM MSE: 5.584704
#   Improvement: -138.16%
# BAC:
#   Sentiment LSTM MSE: 1.512704
#   Baseline LSTM MSE: 0.655832
#   Improvement: -130.65%
# NVDA:
#   Sentiment LSTM MSE: 0.287185
#   Baseline LSTM MSE: 0.137875
#   Improvement: -108.29%
#
# Processing complete:
# Successfully processed: 33/36 tickers
# Results saved to: results/model_comparison_metrics.csv
